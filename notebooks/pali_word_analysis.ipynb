# %%
import pandas as pd
import itertools

# %%
df = pd.read_csv('../pali_canon_hela.csv', index_col=0)

display(df.shape)

df.head()
# Out:
# (284708, 5)
#           nikaya vagga sutta_id  \
# index
# dn1:0.1       dn     1      dn1
# dn1:0.2       dn     1      dn1
# dn1:1.0       dn     1      dn1
# dn1:1.1.1     dn     1      dn1
# dn1:1.1.2     dn     1      dn1
#
#                                                         text  \
# index
# dn1:0.1                                      Dīgha Nikāya 1
# dn1:0.2                                     Brahmajālasutta
# dn1:1.0                                 1. Paribbājakakathā
# dn1:1.1.1                                     Evaṁ me sutaṁ—
# dn1:1.1.2  ekaṁ samayaṁ bhagavā antarā ca rājagahaṁ antar...
#
#                                                    hela_text
# index
# dn1:0.1                                         දීඝ නිකාය 1
# dn1:0.2                                     බ්‍රහ්මජාලසුත්ත
# dn1:1.0                                     1. පරිබ්බාජකකථා
# dn1:1.1.1                                       ඒවං මේ සුතං—
# ...

# %%
df = df.dropna(subset=['text'])
display(df.shape)
# Out:
# (284702, 5)

# %%
pali_verses_list = df['text'].str.split()
all_pali_words = list(itertools.chain.from_iterable(list(pali_words)))

# %%
print(f"len(all_pali_words): {len(all_pali_words)}")



len(set(all_pali_words))
# Out:
# len(all_pali_words): 1588054
# 196906

# %%
#list(pali_words)
