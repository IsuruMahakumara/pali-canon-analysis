# %%
import os
import json
import glob
import numpy as np
from pathlib import Path
import pandas as pd


from fnmatch import fnmatch 

import tqdm

from natsort import natsorted, index_natsorted

# %%
import unicodedata
def to_ascii(text):
    return (
        unicodedata
        .normalize('NFKD', text)
        .encode('ascii', 'ignore')
        .decode('ascii')
    )

print(to_ascii("Sīlakkhandhavagga"))
# Out:
# Silakkhandhavagga

# %% [markdown]
# ## Init

# %%
df = pd.read_csv("pali_canon.csv", index_col=0)
# Out:
# /var/folders/61/zlqrv7wd0252lmrl8999vq340000gn/T/ipykernel_35171/2846154238.py:1: DtypeWarning: Columns (0: text) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("pali_canon.csv", index_col=0)

# %%
df[df['nikaya'] == 'sn']
# Out:
#              nikaya vagga sutta_id  \
# index
# sn1.1:0.1        sn   sn1      NaN
# sn1.1:0.2        sn   sn1      NaN
# sn1.1:0.3        sn   sn1      NaN
# sn1.1:1.1        sn   sn1      NaN
# sn1.1:1.2        sn   sn1      NaN
# ...             ...   ...      ...
# sn56.131:5.4     sn  sn56      NaN
# sn56.131:5.5     sn  sn56      NaN
# sn56.131:5.6     sn  sn56      NaN
# sn56.131:5.7     sn  sn56      NaN
# sn56.131:5.8     sn  sn56      NaN
#
#                                                            text
# index
# sn1.1:0.1                                  Saṁyutta Nikāya 1.1
# sn1.1:0.2                                         1. Naḷavagga
# sn1.1:0.3                                      Oghataraṇasutta
# sn1.1:1.1                                        Evaṁ me sutaṁ—
# sn1.1:1.2     ekaṁ samayaṁ bhagavā sāvatthiyaṁ viharati jeta...
# ...                                                         ...
# sn56.131:5.4                              jhānānāpānasaṁyutaṁ;
# sn56.131:5.5                             Sotāpatti saccañcāti,
# sn56.131:5.6                            mahāvaggoti vuccatīti.
# sn56.131:5.7                   Mahāvaggasaṁyuttapāḷi niṭṭhitā.
# sn56.131:5.8                           Saṁyuttanikāyo samatto.
#
# [43468 rows x 4 columns]

# %%
df_titles = df[df.index.str.contains(":0.2")]


df_titles.iloc[index_natsorted(df_titles.index)]

df_titles
# Out:
#            nikaya   vagga sutta_id                      text
# index
# an1.1:0.2      an     an1      NaN           1. Rūpādivagga
# an1.11:0.2     an     an1      NaN  2. Nīvaraṇappahānavagga
# an1.21:0.2     an     an1      NaN       3. Akammaniyavagga
# an1.31:0.2     an     an1      NaN           4. Adantavagga
# an1.41:0.2     an     an1      NaN    5. Paṇihitaacchavagga
# ...           ...     ...      ...                       ...
# vv81:0.2       kn  vv81:0      NaN             Purisavimāna
# vv82:0.2       kn  vv82:0      NaN             Purisavimāna
# vv83:0.2       kn  vv83:0      NaN             Purisavimāna
# vv84:0.2       kn  vv84:0      NaN             Purisavimāna
# vv85:0.2       kn  vv85:0      NaN             Purisavimāna
#
# [5764 rows x 4 columns]

# %% [markdown]
# ## AN Index Creation

# %%
with open("an-name_root-misc-site.json", "r") as f:
    data = json.load(f)

data = {k.split(".", 1)[1]: v for k, v in data.items()}

data
# Out:
# {'an1': 'Ekakanipāta',
#  'an1-cittapariyadanavagga': 'Cittapariyādānavagga',
#  'an1.1-10': 'Cittapariyādānavagga',
#  'an1-nivaranappahanavagga': 'Nīvaraṇappahānavagga',
#  'an1.11-20': 'Nīvaraṇappahānavagga',
#  'an1-akammaniyavagga': 'Akammaniyavagga',
#  'an1.21-30': 'Akammaniyavagga',
#  'an1-adantavagga': 'Adantavagga',
#  'an1.31-40': 'Adantavagga',
#  'an1-panihitaacchavagga': 'Paṇihitaacchavagga',
#  'an1.41-50': 'Paṇihitaacchavagga',
#  'an1-accharasanghatavagga': 'Accharāsaṅghātavagga',
#  'an1.51-60': 'Accharāsaṅghātavagga',
#  'an1-viriyarambhadivagga': 'Vīriyārambhādivagga',
#  'an1.61-70': 'Vīriyārambhādivagga',
#  'an1-kalyanamittadivagga': 'Kalyāṇamittādivagga',
#  'an1.71-81': 'Kalyāṇamittādivagga',
#  'an1-pamadadivagga': 'Pamādādivagga',
#  'an1.82-97': 'Pamādādivagga',
#  'an1-dutiyapamadadivagga': 'Dutiyapamādādivagga',
#  'an1.98-139': 'Dutiyapamādādivagga',
#  'an1-adhammavagga': 'Adhammavagga',
#  'an1.140-149': 'Adhammavagga',
#  'an1-anapattivagga': 'Anāpattivagga',
#  'an1.150-169': 'Anāpattivagga',
#  'an1-ekapuggalavagga': 'Ekapuggalavagga',
#  'an1.170-187': 'Ekapuggalavagga',
#  'an1-etadaggavagga': 'Etadaggavagga',
#  'an1.188-197': 'Paṭhamavagga',
#  'an1.198-208': 'Dutiyavagga',
#  'an1.209-218': 'Tatiyavagga',
#  'an1.219-234': 'Catutthavagga',
#  'an1.235-247': 'Pañcamavagga',
#  'an1.248-257': 'Chaṭṭhavagga',
#  'an1.258-267': 'Sattamavagga',
#  'an1-atthana': 'Aṭṭhānavagga',
#  'an1.268-277': 'Paṭhamavagga',
#  'an1.278-286': 'Dutiyavagga',
#  'an1.287-295': 'Tatiyavagga',
#  'an1-ekadhamma': 'Ekadhammavagga',
#  'an1.296-305': 'Paṭhamavagga',
#  'an1.306-315': 'Dutiyavagga',
#  'an1.316-332': 'Tatiyavagga',
#  'an1.333-377': 'Catutthavagga',
#  'an1-pasadakaradhammavagga': 'Pasādakaradhammavagga',
#  'an1.378-393': 'Pasādakaradhammavagga',
#  'an1-aparaaccharasanghatavagga': 'Aparaaccharāsaṅghātavagga',
#  'an1.394-574': 'Aparaaccharāsaṅghātavagga',
#  'an1-kayagatasativagga': 'Kāyagatāsativagga',
#  'an1.575-615': 'Kāyagatāsativagga',
#  'an1-amatavagga': 'Amatavagga',
#  'an1.616-627': 'Amatavagga',
#  'an2': 'Dukanipāta',
#  'an2-pathamapannasaka': 'Paṭhamapaṇṇāsaka',
#  'an2-kammakaranavagga': 'Kammakaraṇavagga',
#  'an2.1-10': 'Kammakaraṇavagga',
#  'an2-adhikaranavagga': 'Adhikaraṇavagga',
#  'an2.11-20': 'Adhikaraṇavagga',
#  'an2-balavagga': 'Bālavagga',
#  'an2.21-31': 'Bālavagga',
#  'an2-samacittavagga': 'Samacittavagga',
#  'an2.32-41': 'Samacittavagga',
#  'an2-parisavagga': 'Parisavagga',
#  'an2.42-51': 'Parisavagga',
#  'an2-dutiyapannasaka': 'Dutiyapaṇṇāsaka',
#  'an2-puggalavagga': 'Puggalavagga',
#  'an2.52-63': 'Puggalavagga',
#  'an2-sukhavagga': 'Sukhavagga',
#  'an2.64-76': 'Sukhavagga',
#  'an2-sanimittavagga': 'Sanimittavagga',
#  'an2.77-86': 'Sanimittavagga',
#  'an2-dhammavagga': 'Dhammavagga',
#  'an2.87-97': 'Dhammavagga',
#  'an2-balavagga2': 'Bālavagga',
#  'an2.98-117': 'Bālavagga',
#  'an2-tatiyapannasaka': 'Tatiyapaṇṇāsaka',
#  'an2-asaduppajahavagga': 'Āsāduppajahavagga',
#  'an2.118-129': 'Āsāduppajahavagga',
#  'an2-ayacanavagga': 'Āyācanavagga',
#  'an2.130-140': 'Āyācanavagga',
#  'an2-danavagga': 'Dānavagga',
#  'an2.141-150': 'Dānavagga',
#  'an2-santharavagga': 'Santhāravagga',
#  'an2.151-162': 'Santhāravagga',
#  'an2-samapattivagga': 'Samāpattivagga',
#  'an2.163-179': 'Samāpattivagga',
#  'an2-peyyala': 'Peyyāla',
#  'an2-kodhapeyyalavagga': 'Kodhapeyyālavagga',
#  'an2.180-229': 'Kodhapeyyālavagga',
#  'an2-akusalapeyyalavagga': 'Akusalapeyyālavagga',
#  'an2.230-279': 'Akusalapeyyālavagga',
#  'an2-vinayapeyyalavagga': 'Vinayapeyyālavagga',
#  'an2.280-309': 'Vinayapeyyālavagga',
#  'an2-ragapeyyalavagga': 'Rāgapeyyālavagga',
#  'an2.310-479': 'Rāgapeyyālavagga',
#  'an3': 'Tikanipāta',
#  'an3-pathamapannasaka': 'Paṭhamapaṇṇāsaka',
#  'an3-balavagga': 'Bālavagga',
#  'an3.1': 'Bhayasutta',
#  'an3.2': 'Lakkhaṇasutta',
#  'an3.3': 'Cintīsutta',
#  'an3.4': 'Accayasutta',
#  'an3.5': 'Ayonisosutta',
#  'an3.6': 'Akusalasutta',
#  'an3.7': 'Sāvajjasutta',
#  'an3.8': 'Sabyābajjhasutta',
#  'an3.9': 'Khatasutta',
#  'an3.10': 'Malasutta',
#  'an3-rathakaravagga': 'Rathakāravagga',
#  'an3.11': 'Ñātasutta',
#  'an3.12': 'Sāraṇīyasutta',
#  'an3.13': 'Āsaṁsasutta',
#  'an3.14': 'Cakkavattisutta',
#  'an3.15': 'Sacetanasutta',
#  'an3.16': 'Apaṇṇakasutta',
#  'an3.17': 'Attabyābādhasutta',
#  'an3.18': 'Devalokasutta',
#  'an3.19': 'Paṭhamapāpaṇikasutta',
#  'an3.20': 'Dutiyapāpaṇikasutta',
#  'an3-puggalavagga': 'Puggalavagga',
#  'an3.21': 'Samiddhasutta',
#  'an3.22': 'Gilānasutta',
#  'an3.23': 'Saṅkhārasutta',
#  'an3.24': 'Bahukārasutta',
#  'an3.25': 'Vajirūpamasutta',
#  'an3.26': 'Sevitabbasutta',
#  'an3.27': 'Jigucchitabbasutta',
#  'an3.28': 'Gūthabhāṇīsutta',
#  'an3.29': 'Andhasutta',
#  'an3.30': 'Avakujjasutta',
#  'an3-devadutavagga': 'Devadūtavagga',
#  'an3.31': 'Sabrahmakasutta',
#  'an3.32': 'Ānandasutta',
#  'an3.33': 'Sāriputtasutta',
#  'an3.34': 'Nidānasutta',
#  'an3.35': 'Hatthakasutta',
#  'an3.36': 'Devadūtasutta',
#  'an3.37': 'Catumahārājasutta',
#  'an3.38': 'Dutiyacatumahārājasutta',
#  'an3.39': 'Sukhumālasutta',
#  'an3.40': 'Ādhipateyyasutta',
#  'an3-culavagga': 'Cūḷavagga',
#  'an3.41': 'Sammukhībhāvasutta',
#  'an3.42': 'Tiṭhānasutta',
#  'an3.43': 'Atthavasasutta',
#  'an3.44': 'Kathāpavattisutta',
#  'an3.45': 'Paṇḍitasutta',
#  'an3.46': 'Sīlavantasutta',
#  'an3.47': 'Saṅkhatalakkhaṇasutta',
#  'an3.48': 'Pabbatarājasutta',
#  'an3.49': 'Ātappakaraṇīyasutta',
#  'an3.50': 'Mahācorasutta',
#  'an3-dutiyapannasaka': 'Dutiyapaṇṇāsaka',
#  'an3-brahmanavagga': 'Brāhmaṇavagga',
#  'an3.51': 'Paṭhamadvebrāhmaṇasutta',
#  'an3.52': 'Dutiyadvebrāhmaṇasutta',
#  'an3.53': 'Aññatarabrāhmaṇasutta',
#  'an3.54': 'Paribbājakasutta',
#  'an3.55': 'Nibbutasutta',
#  'an3.56': 'Palokasutta',
#  'an3.57': 'Vacchagottasutta',
#  'an3.58': 'Tikaṇṇasutta',
#  'an3.59': 'Jāṇussoṇisutta',
#  'an3.60': 'Saṅgāravasutta',
#  'an3-mahavagga': 'Mahāvagga',
#  'an3.61': 'Titthāyatanasutta',
#  'an3.62': 'Bhayasutta',
#  'an3.63': 'Venāgapurasutta',
#  'an3.64': 'Sarabhasutta',
#  'an3.65': 'Kesamuttisutta',
#  'an3.66': 'Sāḷhasutta',
#  'an3.67': 'Kathāvatthusutta',
#  'an3.68': 'Aññatitthiyasutta',
#  'an3.69': 'Akusalamūlasutta',
#  'an3.70': 'Uposathasutta',
#  'an3-anandavagga': 'Ānandavagga',
#  'an3.71': 'Channasutta',
#  'an3.72': 'Ājīvakasutta',
#  'an3.73': 'Mahānāmasakkasutta',
#  'an3.74': 'Nigaṇṭhasutta',
#  'an3.75': 'Nivesakasutta',
#  'an3.76': 'Paṭhamabhavasutta',
#  'an3.77': 'Dutiyabhavasutta',
#  'an3.78': 'Sīlabbatasutta',
#  'an3.79': 'Gandhajātasutta',
#  'an3.80': 'Cūḷanikāsutta',
#  'an3-samanavagga': 'Samaṇavagga',
#  'an3.81': 'Samaṇasutta',
#  'an3.82': 'Gadrabhasutta',
#  'an3.83': 'Khettasutta',
#  'an3.84': 'Vajjiputtasutta',
#  'an3.85': 'Sekkhasutta',
#  'an3.86': 'Paṭhamasikkhāsutta',
#  'an3.87': 'Dutiyasikkhāsutta',
#  'an3.88': 'Tatiyasikkhāsutta',
#  'an3.89': 'Paṭhamasikkhattayasutta',
#  'an3.90': 'Dutiyasikkhattayasutta',
#  'an3.91': 'Saṅkavāsutta',
#  'an3-lonakapallavagga': 'Loṇakapallavagga',
#  'an3.92': 'Accāyikasutta',
#  'an3.93': 'Pavivekasutta',
#  'an3.94': 'Saradasutta',
#  'an3.95': 'Parisāsutta',
#  'an3.96': 'Paṭhamaājānīyasutta',
#  'an3.97': 'Dutiyaājānīyasutta',
#  'an3.98': 'Tatiyaājānīyasutta',
#  'an3.99': 'Potthakasutta',
#  'an3.100': 'Loṇakapallasutta',
#  'an3.101': 'Paṁsudhovakasutta',
#  'an3.102': 'Nimittasutta',
#  'an3-tatiyapannasaka': 'Tatiyapaṇṇāsaka',
#  'an3-sambodhavagga': 'Sambodhavagga',
#  'an3.103': 'Pubbevasambodhasutta',
#  'an3.104': 'Paṭhamaassādasutta',
#  'an3.105': 'Dutiyaassādasutta',
#  'an3.106': 'Samaṇabrāhmaṇasutta',
#  'an3.107': 'Ruṇṇasutta',
#  'an3.108': 'Atittisutta',
#  'an3.109': 'Arakkhitasutta',
#  'an3.110': 'Byāpannasutta',
#  'an3.111': 'Paṭhamanidānasutta',
#  'an3.112': 'Dutiyanidānasutta',
#  'an3-apayikavagga': 'Āpāyikavagga',
#  'an3.113': 'Āpāyikasutta',
#  'an3.114': 'Dullabhasutta',
#  'an3.115': 'Appameyyasutta',
#  'an3.116': 'Āneñjasutta',
#  'an3.117': 'Vipattisampadāsutta',
#  'an3.118': 'Apaṇṇakasutta',
#  'an3.119': 'Kammantasutta',
#  'an3.120': 'Paṭhamasoceyyasutta',
#  'an3.121': 'Dutiyasoceyyasutta',
#  'an3.122': 'Moneyyasutta',
#  'an3-kusinaravagga': 'Kusināravagga',
#  'an3.123': 'Kusinārasutta',
#  'an3.124': 'Bhaṇḍanasutta',
#  'an3.125': 'Gotamakacetiyasutta',
#  'an3.126': 'Bharaṇḍukālāmasutta',
#  'an3.127': 'Hatthakasutta',
#  'an3.128': 'Kaṭuviyasutta',
#  'an3.129': 'Paṭhamaanuruddhasutta',
#  'an3.130': 'Dutiyaanuruddhasutta',
#  'an3.131': 'Paṭicchannasutta',
#  'an3.132': 'Lekhasutta',
#  'an3-yodhajivavagga': 'Yodhājīvavagga',
#  'an3.133': 'Yodhājīvasutta',
#  'an3.134': 'Parisāsutta',
#  'an3.135': 'Mittasutta',
#  'an3.136': 'Uppādāsutta',
#  'an3.137': 'Kesakambalasutta',
#  'an3.138': 'Sampadāsutta',
#  'an3.139': 'Vuddhisutta',
#  'an3.140': 'Assakhaḷuṅkasutta',
#  'an3.141': 'Assaparassasutta',
#  'an3.142': 'Assājānīyasutta',
#  'an3.143': 'Paṭhamamoranivāpasutta',
#  'an3.144': 'Dutiyamoranivāpasutta',
#  'an3.145': 'Tatiyamoranivāpasutta',
#  'an3-mangalavagga': 'Maṅgalavagga',
#  'an3.146': 'Akusalasutta',
#  'an3.147': 'Sāvajjasutta',
#  'an3.148': 'Visamasutta',
#  'an3.149': 'Asucisutta',
#  'an3.150': 'Paṭhamakhatasutta',
#  'an3.151': 'Dutiyakhatasutta',
#  'an3.152': 'Tatiyakhatasutta',
#  'an3.153': 'Catutthakhatasutta',
#  'an3.154': 'Vandanāsutta',
#  'an3.155': 'Pubbaṇhasutta',
#  'an3-patipadavagga': 'Patipadāvagga',
#  'an3.156-162': 'Acelakavagga',
#  'an3-kammapathapeyyavagga': 'Kammapathapeyyāvagga',
#  'an3.163-182': 'Kammapathapeyyāla',
#  'an3-ragadipeyyalavagga': 'Rāgādipeyyālavagga',
#  'an3.183-352': 'Rāgapeyyāla',
#  'an4': 'Catukkanipāta',
#  'an4-pathamapannasaka': 'Paṭhamapaṇṇāsaka',
#  'an4-bhandagamavagga': 'Bhaṇḍagāmavagga',
#  'an4.1': 'Anubuddhasutta',
#  'an4.2': 'Papatitasutta',
#  'an4.3': 'Paṭhamakhatasutta',
#  'an4.4': 'Dutiyakhatasutta',
#  'an4.5': 'Anusotasutta',
#  'an4.6': 'Appassutasutta',
#  'an4.7': 'Sobhanasutta',
#  'an4.8': 'Vesārajjasutta',
#  'an4.9': 'Taṇhuppādasutta',
#  'an4.10': 'Yogasutta',
#  'an4-caravagga': 'Caravagga',
#  'an4.11': 'Carasutta',
#  'an4.12': 'Sīlasutta',
#  'an4.13': 'Padhānasutta',
#  'an4.14': 'Saṁvarasutta',
#  'an4.15': 'Paññattisutta',
#  'an4.16': 'Sokhummasutta',
#  'an4.17': 'Paṭhamaagatisutta',
#  'an4.18': 'Dutiyaagatisutta',
#  'an4.19': 'Tatiyaagatisutta',
#  'an4.20': 'Bhattuddesakasutta',
#  'an4-uruvelavagga': 'Uruvelavagga',
#  'an4.21': 'Paṭhamauruvelasutta',
#  'an4.22': 'Dutiyauruvelasutta',
#  'an4.23': 'Lokasutta',
#  'an4.24': 'Kāḷakārāmasutta',
#  'an4.25': 'Brahmacariyasutta',
#  'an4.26': 'Kuhasutta',
#  'an4.27': 'Santuṭṭhisutta',
#  'an4.28': 'Ariyavaṁsasutta',
#  'an4.29': 'Dhammapadasutta',
#  'an4.30': 'Paribbājakasutta',
#  'an4-cakkavagga': 'Cakkavagga',
#  'an4.31': 'Cakkasutta',
#  'an4.32': 'Saṅgahasutta',
#  'an4.33': 'Sīhasutta',
#  'an4.34': 'Aggappasādasutta',
#  'an4.35': 'Vassakārasutta',
#  'an4.36': 'Doṇasutta',
#  'an4.37': 'Aparihāniyasutta',
#  'an4.38': 'Patilīnasutta',
#  'an4.39': 'Ujjayasutta',
#  'an4.40': 'Udāyīsutta',
#  'an4-rohitassavagga': 'Rohitassavagga',
#  'an4.41': 'Samādhibhāvanāsutta',
#  'an4.42': 'Pañhabyākaraṇasutta',
#  'an4.43': 'Paṭhamakodhagarusutta',
#  'an4.44': 'Dutiyakodhagarusutta',
#  'an4.45': 'Rohitassasutta',
#  'an4.46': 'Dutiyarohitassasutta',
#  'an4.47': 'Suvidūrasutta',
#  'an4.48': 'Visākhasutta',
#  'an4.49': 'Vipallāsasutta',
#  'an4.50': 'Upakkilesasutta',
#  'an4-dutiyapannasaka': 'Dutiyapaṇṇāsaka',
#  'an4-punnabhisandavagga': 'Puññābhisandavagga',
#  'an4.51': 'Paṭhamapuññābhisandasutta',
#  'an4.52': 'Dutiyapuññābhisandasutta',
#  'an4.53': 'Paṭhamasaṁvāsasutta',
#  'an4.54': 'Dutiyasaṁvāsasutta',
#  'an4.55': 'Paṭhamasamajīvīsutta',
#  'an4.56': 'Dutiyasamajīvīsutta',
#  'an4.57': 'Suppavāsāsutta',
#  'an4.58': 'Sudattasutta',
#  'an4.59': 'Bhojanasutta',
#  'an4.60': 'Gihisāmīcisutta',
#  'an4-pattakammavagga': 'Pattakammavagga',
#  'an4.61': 'Pattakammasutta',
#  'an4.62': 'Ānaṇyasutta',
#  'an4.63': 'Brahmasutta',
#  'an4.64': 'Nirayasutta',
#  'an4.65': 'Rūpasutta',
#  'an4.66': 'Sarāgasutta',
#  'an4.67': 'Ahirājasutta',
#  'an4.68': 'Devadattasutta',
#  'an4.69': 'Padhānasutta',
#  'an4.70': 'Adhammikasutta',
#  'an4-apannakavagga': 'Apaṇṇakavagga',
#  'an4.71': 'Padhānasutta',
#  'an4.72': 'Sammādiṭṭhisutta',
#  'an4.73': 'Sappurisasutta',
#  'an4.74': 'Paṭhamaaggasutta',
#  'an4.75': 'Dutiyaaggasutta',
#  'an4.76': 'Kusinārasutta',
#  'an4.77': 'Acinteyyasutta',
#  'an4.78': 'Dakkhiṇasutta',
#  'an4.79': 'Vaṇijjasutta',
#  'an4.80': 'Kambojasutta',
#  'an4-macalavagga': 'Macalavagga',
#  'an4.81': 'Pāṇātipātasutta',
#  'an4.82': 'Musāvādasutta',
#  'an4.83': 'Avaṇṇārahasutta',
#  'an4.84': 'Kodhagarusutta',
#  'an4.85': 'Tamotamasutta',
#  'an4.86': 'Oṇatoṇatasutta',
#  'an4.87': 'Puttasutta',
#  'an4.88': 'Saṁyojanasutta',
#  'an4.89': 'Sammādiṭṭhisutta',
#  'an4.90': 'Khandhasutta',
#  'an4-asuravagga': 'Asuravagga',
#  'an4.91': 'Asurasutta',
#  'an4.92': 'Paṭhamasamādhisutta',
#  'an4.93': 'Dutiyasamādhisutta',
#  'an4.94': 'Tatiyasamādhisutta',
#  'an4.95': 'Chavālātasutta',
#  'an4.96': 'Rāgavinayasutta',
#  'an4.97': 'Khippanisantisutta',
#  'an4.98': 'Attahitasutta',
#  'an4.99': 'Sikkhāpadasutta',
#  'an4.100': 'Potaliyasutta',
#  'an4-tatiyapannasaka': 'Tatiyapaṇṇāsaka',
#  'an4-valahakavagga': 'Valāhakavagga',
#  'an4.101': 'Paṭhamavalāhakasutta',
#  'an4.102': 'Dutiyavalāhakasutta',
#  'an4.103': 'Kumbhasutta',
#  'an4.104': 'Udakarahadasutta',
#  'an4.105': 'Ambasutta',
#  'an4.106': '(Dutiyaambasutta)',
#  'an4.107': 'Mūsikasutta',
#  'an4.108': 'Balībaddasutta',
#  'an4.109': 'Rukkhasutta',
#  'an4.110': 'Āsīvisasutta',
#  'an4-kesivagga': 'Kesivagga',
#  'an4.111': 'Kesisutta',
#  'an4.112': 'Javasutta',
#  'an4.113': 'Patodasutta',
#  'an4.114': 'Nāgasutta',
#  'an4.115': 'Ṭhānasutta',
#  'an4.116': 'Appamādasutta',
#  'an4.117': 'Ārakkhasutta',
#  'an4.118': 'Saṁvejanīyasutta',
#  'an4.119': 'Paṭhamabhayasutta',
#  'an4.120': 'Dutiyabhayasutta',
#  'an4-bhayavagga': 'Bhayavagga',
#  'an4.121': 'Attānuvādasutta',
#  'an4.122': 'Ūmibhayasutta',
#  'an4.123': 'Paṭhamanānākaraṇasutta',
#  'an4.124': 'Dutiyanānākaraṇasutta',
#  'an4.125': 'Paṭhamamettāsutta',
#  'an4.126': 'Dutiyamettāsutta',
#  'an4.127': 'Paṭhamatathāgataacchariyasutta',
#  'an4.128': 'Dutiyatathāgataacchariyasutta',
#  'an4.129': 'Ānandaacchariyasutta',
#  'an4.130': 'Cakkavattiacchariyasutta',
#  'an4-puggalavagga': 'Puggalavagga',
#  'an4.131': 'Saṁyojanasutta',
#  'an4.132': 'Paṭibhānasutta',
#  'an4.133': 'Ugghaṭitaññūsutta',
#  'an4.134': 'Uṭṭhānaphalasutta',
#  'an4.135': 'Sāvajjasutta',
#  'an4.136': 'Paṭhamasīlasutta',
#  'an4.137': 'Dutiyasīlasutta',
#  'an4.138': 'Nikaṭṭhasutta',
#  'an4.139': 'Dhammakathikasutta',
#  'an4.140': 'Vādīsutta',
#  'an4-abhavagga': 'Ābhāvagga',
#  'an4.141': 'Ābhāsutta',
#  'an4.142': 'Pabhāsutta',
#  'an4.143': 'Ālokasutta',
#  'an4.144': 'Obhāsasutta',
#  'an4.145': 'Pajjotasutta',
#  'an4.146': 'Paṭhamakālasutta',
#  'an4.147': 'Dutiyakālasutta',
#  'an4.148': 'Duccaritasutta',
#  'an4.149': 'Sucaritasutta',
#  'an4.150': 'Sārasutta',
#  'an4-catutthapannasaka': 'Catutthapaṇṇāsaka',
#  'an4-indriyavagga': 'Indriyavagga',
#  'an4.151': 'Indriyasutta',
#  'an4.152': 'Saddhābalasutta',
#  'an4.153': 'Paññābalasutta',
#  'an4.154': 'Satibalasutta',
#  'an4.155': 'Paṭisaṅkhānabalasutta',
#  'an4.156': 'Kappasutta',
#  'an4.157': 'Rogasutta',
#  'an4.158': 'Parihānisutta',
#  'an4.159': 'Bhikkhunīsutta',
#  'an4.160': 'Sugatavinayasutta',
#  'an4-patipadavagga': 'Paṭipadāvagga',
#  'an4.161': 'Saṁkhittasutta',
#  'an4.162': 'Vitthārasutta',
#  'an4.163': 'Asubhasutta',
#  'an4.164': 'Paṭhamakhamasutta',
#  'an4.165': 'Dutiyakhamasutta',
#  'an4.166': 'Ubhayasutta',
#  'an4.167': 'Mahāmoggallānasutta',
#  'an4.168': 'Sāriputtasutta',
#  'an4.169': 'Sasaṅkhārasutta',
#  'an4.170': 'Yuganaddhasutta',
#  'an4-sancetaniyavagga': 'Sañcetaniyavagga',
#  'an4.171': 'Cetanāsutta',
#  'an4.172': 'Vibhattisutta',
#  'an4.173': 'Mahākoṭṭhikasutta',
#  'an4.174': 'Ānandasutta',
#  'an4.175': 'Upavāṇasutta',
#  'an4.176': 'Āyācanasutta',
#  'an4.177': 'Rāhulasutta',
#  'an4.178': 'Jambālīsutta',
#  'an4.179': 'Nibbānasutta',
#  'an4.180': 'Mahāpadesasutta',
#  'an4-brahmanavagga': 'Brāhmaṇavagga',
#  'an4.181': 'Yodhājīvasutta',
#  'an4.182': 'Pāṭibhogasutta',
#  'an4.183': 'Sutasutta',
#  'an4.184': 'Abhayasutta',
#  'an4.185': 'Brāhmaṇasaccasutta',
#  'an4.186': 'Ummaggasutta',
#  'an4.187': 'Vassakārasutta',
#  'an4.188': 'Upakasutta',
#  'an4.189': 'Sacchikaraṇīyasutta',
#  'an4.190': 'Uposathasutta',
#  'an4-mahavagga': 'Mahāvagga',
#  'an4.191': 'Sotānugatasutta',
#  'an4.192': 'Ṭhānasutta',
#  'an4.193': 'Bhaddiyasutta',
#  'an4.194': 'Sāmugiyasutta',
#  'an4.195': 'Vappasutta',
#  'an4.196': 'Sāḷhasutta',
#  'an4.197': 'Mallikādevīsutta',
#  'an4.198': 'Attantapasutta',
#  'an4.199': 'Taṇhāsutta',
#  'an4.200': 'Pemasutta',
#  'an4-pancamapannasaka': 'Pañcamapaṇṇāsaka',
#  'an4-sappurisavagga': 'Sappurisavagga',
#  'an4.201': 'Sikkhāpadasutta',
#  'an4.202': 'Assaddhasutta',
#  'an4.203': 'Sattakammasutta',
#  'an4.204': 'Dasakammasutta',
#  'an4.205': 'Aṭṭhaṅgikasutta',
#  'an4.206': 'Dasamaggasutta',
#  'an4.207': 'Paṭhamapāpadhammasutta',
#  'an4.208': 'Dutiyapāpadhammasutta',
#  'an4.209': 'Tatiyapāpadhammasutta',
#  'an4.210': 'Catutthapāpadhammasutta',
#  'an4-parisavagga': 'Parisāvagga',
#  'an4.211': 'Parisāsutta',
#  'an4.212': 'Diṭṭhisutta',
#  'an4.213': 'Akataññutāsutta',
#  'an4.214': 'Pāṇātipātīsutta',
#  'an4.215': 'Paṭhamamaggasutta',
#  'an4.216': 'Dutiyamaggasutta',
#  'an4.217': 'Paṭhamavohārapathasutta',
#  'an4.218': 'Dutiyavohārapathasutta',
#  'an4.219': 'Ahirikasutta',
#  'an4.220': 'Dussīlasutta',
#  'an4-duccaritavagga': 'Duccaritavagga',
#  'an4.221': 'Duccaritasutta',
#  'an4.222': 'Diṭṭhisutta',
#  'an4.223': 'Akataññutāsutta',
#  'an4.224': 'Pāṇātipātīsutta',
#  'an4.225': 'Paṭhamamaggasutta',
#  'an4.226': 'Dutiyamaggasutta',
#  'an4.227': 'Paṭhamavohārapathasutta',
#  'an4.228': 'Dutiyavohārapathasutta',
#  'an4.229': 'Ahirikasutta',
#  'an4.230': 'Duppaññasutta',
#  'an4.231': 'Kavisutta',
#  'an4-kammavagga': 'Kammavagga',
#  'an4.232': 'Saṁkhittasutta',
#  'an4.233': 'Vitthārasutta',
#  'an4.234': 'Soṇakāyanasutta',
#  'an4.235': 'Paṭhamasikkhāpadasutta',
#  'an4.236': 'Dutiyasikkhāpadasutta',
#  'an4.237': 'Ariyamaggasutta',
#  'an4.238': 'Bojjhaṅgasutta',
#  'an4.239': 'Sāvajjasutta',
#  'an4.240': 'Abyābajjhasutta',
#  'an4.241': 'Samaṇasutta',
#  'an4.242': 'Sappurisānisaṁsasutta',
#  'an4-apattibhayavagga': 'Āpattibhayavagga',
#  'an4.243': 'Saṁghabhedakasutta',
#  'an4.244': 'Āpattibhayasutta',
#  'an4.245': 'Sikkhānisaṁsasutta',
#  'an4.246': 'Seyyāsutta',
#  'an4.247': 'Thūpārahasutta',
#  'an4.248': 'Paññāvuddhisutta',
#  'an4.249': 'Bahukārasutta',
#  'an4.250': 'Paṭhamavohārasutta',
#  'an4.251': 'Dutiyavohārasutta',
#  'an4.252': 'Tatiyavohārasutta',
#  'an4.253': 'Catutthavohārasutta',
#  'an4-abhinnavagga': 'Abhiññāvagga',
#  'an4.254': 'Abhiññāsutta',
#  'an4.255': 'Pariyesanāsutta',
#  'an4.256': 'Saṅgahavatthusutta',
#  'an4.257': 'Mālukyaputtasutta',
#  'an4.258': 'Kulasutta',
#  'an4.259': 'Paṭhamaājānīyasutta',
#  'an4.260': 'Dutiyaājānīyasutta',
#  'an4.261': 'Balasutta',
#  'an4.262': 'Araññasutta',
#  'an4.263': 'Kammasutta',
#  'an4-kammapathavagga': 'Kammapathavagga',
#  'an4.264': 'Pāṇātipātīsutta',
#  'an4.265': 'Adinnādāyīsutta',
#  'an4.266': 'Micchācārīsutta',
#  'an4.267': 'Musāvādīsutta',
#  'an4.268': 'Pisuṇavācāsutta',
#  'an4.269': 'Pharusavācāsutta',
#  'an4.270': 'Samphappalāpasutta',
#  'an4.271': 'Abhijjhālusutta',
#  'an4.272': 'Byāpannacittasutta',
#  'an4.273': 'Micchādiṭṭhisutta',
#  'an4-ragapeyyala': 'Rāgapeyyāla',
#  'an4.274': 'Satipaṭṭhānasutta',
#  'an4.275': 'Sammappadhānasutta',
#  'an4.276': 'Iddhipādasutta',
#  'an4.277-303': 'Pariññādisutta',
#  'an4.304-783': 'Dosaabhiññādisutta',
#  'an5': 'Pañcakanipāta',
#  'an5-pathamapannasaka': 'Paṭhamapaṇṇāsaka',
#  'an5-sekhabalavagga': 'Sekhabalavagga',
#  'an5.1': 'Saṁkhittasutta',
#  'an5.2': 'Vitthatasutta',
#  'an5.3': 'Dukkhasutta',
#  'an5.4': 'Yathābhatasutta',
#  'an5.5': 'Sikkhāsutta',
#  'an5.6': 'Samāpattisutta',
#  'an5.7': 'Kāmasutta',
#  'an5.8': 'Cavanasutta',
#  'an5.9': 'Paṭhamaagāravasutta',
#  'an5.10': 'Dutiyaagāravasutta',
#  'an5-balavagga': 'Balavagga',
#  'an5.11': 'Ananussutasutta',
#  'an5.12': 'Kūṭasutta',
#  'an5.13': 'Saṁkhittasutta',
#  'an5.14': 'Vitthatasutta',
#  'an5.15': 'Daṭṭhabbasutta',
#  'an5.16': 'Punakūṭasutta',
#  'an5.17': 'Paṭhamahitasutta',
#  'an5.18': 'Dutiyahitasutta',
#  'an5.19': 'Tatiyahitasutta',
#  'an5.20': 'Catutthahitasutta',
#  'an5-pancangikavagga': 'Pañcaṅgikavagga',
#  'an5.21': 'Paṭhamaagāravasutta',
#  'an5.265-271': 'Aparadutiyajhānasuttādi',
#  'an5-sammutipeyyala': 'Sammutipeyyāla',
#  'an5.272': 'Bhattuddesakasutta',
#  'an5.273-285': 'Senāsanapaññāpakasuttādi',
#  'an5-sikkhapadapeyyala': 'Sikkhāpadapeyyāla',
#  'an5.286': 'Bhikkhusutta',
#  'an5.287-292': 'Bhikkhunīsuttādi',
#  'an5.293': 'Ājīvakasutta',
#  'an5.294-302': 'Nigaṇṭhasuttādi',
#  'an5-ragapeyyala': 'Rāgapeyyāla',
#  'an5.303': '',
#  'an5.304': '',
#  'an5.305': '',
#  'an5.306': '',
#  'an5.307': '',
#  'an5.308-1152': '',
#  'an6': 'Chakkanipāta',
#  'an6-pathamapannasaka': 'Paṭhamapaṇṇāsaka',
#  'an6-ahuneyyavagga': 'Āhuneyyavagga',
#  'an6.1': 'Paṭhamaāhuneyyasutta',
#  'an6.2': 'Dutiyaāhuneyyasutta',
#  'an6.3': 'Indriyasutta',
#  'an6.4': 'Balasutta',
#  'an6.5': 'Paṭhamaājānīyasutta',
#  'an6.6': 'Dutiyaājānīyasutta',
#  'an6.7': 'Tatiyaājānīyasutta',
#  'an6.8': 'Anuttariyasutta',
#  'an6.9': 'Anussatiṭṭhānasutta',
#  'an6.10': 'Mahānāmasutta',
#  'an6-saraniyavagga': 'Sāraṇīyavagga',
#  'an6.11': 'Paṭhamasāraṇīyasutta',
#  'an6.12': 'Dutiyasāraṇīyasutta',
#  'an6.13': 'Nissāraṇīyasutta',
#  'an6.14': 'Bhaddakasutta',
#  'an6.15': 'Anutappiyasutta',
#  'an6.16': 'Nakulapitusutta',
#  'an6.17': 'Soppasutta',
#  'an6.18': 'Macchabandhasutta',
#  'an6.19': 'Paṭhamamaraṇassatisutta',
#  'an6.20': 'Dutiyamaraṇassatisutta',
#  'an6-anuttariyavagga': 'Anuttariyavagga',
#  'an6.21': 'Sāmakasutta',
#  'an6.22': 'Aparihāniyasutta',
#  'an6.23': 'Bhayasutta',
#  'an6.24': 'Himavantasutta',
#  'an6.25': 'Anussatiṭṭhānasutta',
#  'an6.26': 'Mahākaccānasutta',
#  'an6.27': 'Paṭhamasamayasutta',
#  'an6.28': 'Dutiyasamayasutta',
#  'an6.29': 'Udāyīsutta',
#  'an6.30': 'Anuttariyasutta',
#  'an6-pathamapannasaka-devatavagga': 'Devatāvagga',
#  'an6.31': 'Sekhasutta',
#  'an6.32': 'Paṭhamaaparihānasutta',
#  'an6.33': 'Dutiyaaparihānasutta',
#  'an6.34': 'Mahāmoggallānasutta',
#  'an6.35': 'Vijjābhāgiyasutta',
#  'an6.36': 'Vivādamūlasutta',
#  'an6.37': 'Chaḷaṅgadānasutta',
#  'an6.38': 'Attakārīsutta',
#  'an6.39': 'Nidānasutta',
#  'an6.40': 'Kimilasutta',
#  'an6.41': 'Dārukkhandhasutta',
#  'an6.42': 'Nāgitasutta',
#  'an6-dhammikavagga': 'Dhammikavagga',
#  'an6.43': 'Nāgasutta',
#  'an6.44': 'Migasālāsutta',
#  'an6.45': 'Iṇasutta',
#  'an6.46': 'Mahācundasutta',
#  'an6.47': 'Paṭhamasandiṭṭhikasutta',
#  'an6.48': 'Dutiyasandiṭṭhikasutta',
#  'an6.49': 'Khemasutta',
#  'an6.50': 'Indriyasaṁvarasutta',
#  'an6.51': 'Ānandasutta',
#  'an6.52': 'Khattiyasutta',
#  'an6.53': 'Appamādasutta',
#  'an6.54': 'Dhammikasutta',
#  'an6-dutiyapannasaka': 'Dutiyapaṇṇāsaka',
#  'an6-mahavagga': 'Mahāvagga',
#  'an6.55': 'Soṇasutta',
#  'an6.56': 'Phaggunasutta',
#  'an6.57': 'Chaḷabhijātisutta',
#  'an6.58': 'Āsavasutta',
#  'an6.59': 'Dārukammikasutta',
#  'an6.60': 'Hatthisāriputtasutta',
#  'an6.61': 'Majjhesutta',
#  'an6.62': 'Purisindriyañāṇasutta',
#  'an6.63': 'Nibbedhikasutta',
#  'an6.64': 'Sīhanādasutta',
#  'an6-dutiyapannasaka-devatavagga': 'Devatāvagga',
#  'an6.65': 'Anāgāmiphalasutta',
#  'an6.66': 'Arahattasutta',
#  'an6.67': 'Mittasutta',
#  'an6.68': 'Saṅgaṇikārāmasutta',
#  'an6.69': 'Devatāsutta',
#  'an6.70': 'Samādhisutta',
#  'an6.71': 'Sakkhibhabbasutta',
#  'an6.72': 'Balasutta',
#  'an6.73': 'Paṭhamatajjhānasutta',
#  'an6.74': 'Dutiyatajjhānasutta',
#  'an6-arahattavagga': 'Arahattavagga',
#  'an6.75': 'Dukkhasutta',
#  'an6.76': 'Arahattasutta',
#  'an6.77': 'Uttarimanussadhammasutta',
#  'an6.78': 'Sukhasomanassasutta',
#  'an6.79': 'Adhigamasutta',
#  'an6.80': 'Mahantattasutta',
#  'an6.81': 'Paṭhamanirayasutta',
#  'an6.82': 'Dutiyanirayasutta',
#  'an6.83': 'Aggadhammasutta',
#  'an6.84': 'Rattidivasasutta',
#  'an6-sitivagga': 'Sītivagga',
#  'an6.85': 'Sītibhāvasutta',
#  'an6.86': 'Āvaraṇasutta',
#  'an6.87': 'Voropitasutta',
#  'an6.88': 'Sussūsatisutta',
#  'an6.89': 'Appahāyasutta',
#  'an6.90': 'Pahīnasutta',
#  'an6.91': 'Abhabbasutta',
#  'an6.92': 'Paṭhamaabhabbaṭṭhānasutta',
#  'an6.93': 'Dutiyaabhabbaṭṭhānasutta',
#  'an6.94': 'Tatiyaabhabbaṭṭhānasutta',
#  ...}

# %%
indexed_dict = {}

nipata_key = None
vagga_key = None


for k,v in data.items():
    if v.endswith('nipāta'):
        nipata_key = v
        indexed_dict.setdefault(nipata_key, {})
        continue

    elif '-' in k and '.' not in k:
        vagga_key = v
        indexed_dict[nipata_key].setdefault(vagga_key, {})
        continue


    elif '.' in k:
        indexed_dict[nipata_key][vagga_key][k] = v

        if 'an2' in k:
            print(nipata_key, vagga_key, k)
        
        
        

with open("an-index-tree.json", "w", encoding="utf-8") as f:
    json.dump(indexed_dict, f, ensure_ascii=False, indent=4)
# Out:
# Dukanipāta Kammakaraṇavagga an2.1-10
# Dukanipāta Adhikaraṇavagga an2.11-20
# Dukanipāta Bālavagga an2.21-31
# Dukanipāta Samacittavagga an2.32-41
# Dukanipāta Parisavagga an2.42-51
# Dukanipāta Puggalavagga an2.52-63
# Dukanipāta Sukhavagga an2.64-76
# Dukanipāta Sanimittavagga an2.77-86
# Dukanipāta Dhammavagga an2.87-97
# Dukanipāta Bālavagga an2.98-117
# Dukanipāta Āsāduppajahavagga an2.118-129
# Dukanipāta Āyācanavagga an2.130-140
# Dukanipāta Dānavagga an2.141-150
# Dukanipāta Santhāravagga an2.151-162
# Dukanipāta Samāpattivagga an2.163-179
# Dukanipāta Kodhapeyyālavagga an2.180-229
# Dukanipāta Akusalapeyyālavagga an2.230-279
# Dukanipāta Vinayapeyyālavagga an2.280-309
# Dukanipāta Rāgapeyyālavagga an2.310-479

# %%
nipata_key="Ekakanipāta"

print(repr(nipata_key))
print(nipata_key == "Ekakanipāta")
# Out:
# 'Ekakanipāta'
# True

# %% [markdown]
# ## SN Index Creation

# %%
with open("pali_canon_index.json", "r") as f:
    data = json.load(f)

# %%
data_new = {}
for k, v in data.items():
    k = k.split(":")[1].split(".", 1)[1]
    data_new[k] = v

# %%
indexed_dict = {}
vs_key = None
s_key = None
vagga_key = None

for k,v in data_new.items():


    if v.endswith('vaggasaṁyutta'):
        vs_key = v
        indexed_dict.setdefault(vs_key, {})
        continue 

    elif v.endswith('saṁyutta'):
        s_key = f"{k}.{v}"
        indexed_dict[vs_key].setdefault(s_key, {})
        continue

    elif v.endswith('vagga') :
        vagga_key = v
        indexed_dict[vs_key][s_key].setdefault(vagga_key, {})
        indexed_dict[vs_key][s_key][vagga_key].setdefault(k, {})
        continue

    elif v.endswith('sutta'):
        
  
        indexed_dict[vs_key][s_key][vagga_key][k]=v

# %%
suffix = "vagga"

filtered_indexed_dict = {
    vs_k: {
        samyutta_k: {
            vagga_k: {
                sutta_k: sutta_v
                for sutta_k, sutta_v in vagga_v.items()
                if not sutta_k.endswith(suffix)
            }
            for vagga_k, vagga_v in samyutta_v.items()
        }
        for samyutta_k, samyutta_v in vs_v.items()
    }
    for vs_k, vs_v in indexed_dict.items()
}

# %%
with open("result.json", "w", encoding="utf-8") as f:
    json.dump(filtered_indexed_dict, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## DN Index

# %%
with open("../dn-name_root-misc-site.json", "r") as f:
    data = json.load(f)

Silakkhandhavagga={}
Mahavagga={}
Pathikavagga={}


data = { k.split(".", 1)[1]: v for k, v in data.items()}
vagga = {to_ascii(v): 'k' for k, v in data.items() if v.endswith('vagga')}

for k, v in data.items():

    try:
        num = int("".join([char for char in k if char.isdigit()]))
    except:
        continue
    

    if num<14:
        Silakkhandhavagga[k] = v
        
    elif num<24:
        Mahavagga[k] = v

    else:
        Pathikavagga[k] = v



dn_index = {
    "Silakkhandhavagga": Silakkhandhavagga,
    "Mahavagga": Mahavagga,
    "Pathikavagga": Pathikavagga
}

with open("../dn-index-tree.json", "w", encoding="utf-8") as f:
    json.dump(dn_index, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## MN Index

# %%
with open("../mn-name_root-misc-site.json", "r") as f:
    data = json.load(f)

# Silakkhandhavagga={}
# Mahavagga={}
# Pathikavagga={}


data = { k.split(".", 1)[1]: v for k, v in data.items()}
sutta = { k : to_ascii(v) for k, v in data.items() if v.endswith('sutta')}
vagga = {to_ascii(v): 'k' for k, v in data.items() if v.endswith('vagga')}
pannasa = {to_ascii(v): 'k' for k, v in data.items() if v.endswith('paṇṇāsa')}

# for k, v in data.items():

#     try:
#         num = int("".join([char for char in k if char.isdigit()]))
#     except:
#         continue
    

#     if num<14:
#         Silakkhandhavagga[k] = v
        
#     elif num<24:
#         Mahavagga[k] = v

#     else:s
#         Pathikavagga[k] = v
pannasa
# data
# Out:
# {'Mulapannasa': 'k', 'Majjhimapannasa': 'k', 'Uparipannasa': 'k'}

# %% [markdown]
# ## KN Index

# %% [markdown]
# ## ABHIDHAMMA

# %% [markdown]
# #### Abhidhamma Text

# %%
root=Path('../pali_cannon/abhidhamma/')

dfs = []

for file_path in root.rglob("*.json"):
    


    # Get relative path parts
    relative_path = file_path.relative_to(root)
    parts = relative_path.parts
    
    # Separate folders and filename
    *folders, filename = parts
   

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

        df = pd.DataFrame(data.items(), columns=["verse_id", "text"])
        dfs.append(df)

        try:
             pakarana = folders[0] 
             df['pakarana'] = pakarana
        except:
            print(f"Error: {file_path}")
            pass
        
        try:
            chapter = folders[1]
            df['chapter'] = chapter
        except:
            df['chapter'] = df['verse_id'].str.split(":").str[0]

            pass

        if  df.empty:
            print(f"Empty df: {file_path}")
            

  

df_final = pd.concat(dfs)



#replace patthana with pt for verse_id and chapter consistency
df_final['chapter'] = df_final['chapter'].str.replace("patthana", "pt")
df_final['verse_id'] = df_final['verse_id'].str.replace("patthana", "pt")
df_final['pakarana'] = df_final['pakarana'].str.replace("patthana", "pt")


df_final['subchapter'] = df_final['verse_id'].astype(str).str.split(pat=":", n=1).str[0]



df_final = df_final[['pakarana', 'chapter', 'subchapter', 'text', 'verse_id']]


df_final['pakarana_id'] = df_final['pakarana'].map({'ds':1, 'vb':2, 'dt':3, 'pp':4, 'kv':5, 'ya':6, 'pt':7})

df_final.set_index('verse_id', inplace=True)






index_natsorted(df_final.index)
df_final.sort_values(by='pakarana_id', inplace=True)

df_final.drop(columns=['pakarana_id'], inplace=True)


df_final.to_csv("../abhidhamma_text.csv")


df_final
# Out:
#                pakarana chapter subchapter  \
# verse_id
# ds1.1:0.1            ds     ds1      ds1.1
# ds2.1.1:87.2         ds     ds2    ds2.1.1
# ds2.1.1:87.1         ds     ds2    ds2.1.1
# ds2.1.1:86.4         ds     ds2    ds2.1.1
# ds2.1.1:86.3         ds     ds2    ds2.1.1
# ...                 ...     ...        ...
# pt2.11:157.1         pt     pt2     pt2.11
# pt2.11:157.0.2       pt     pt2     pt2.11
# pt2.11:157.0.1       pt     pt2     pt2.11
# pt2.11:175.1         pt     pt2     pt2.11
# pt1.13:218.1         pt     pt1     pt1.13
#
#                                                              text
# verse_id
# ds1.1:0.1                                          Dhammasaṅgaṇī
# ds2.1.1:87.2    Saddhindriyaṁ, vīriyindriyaṁ, satindriyaṁ, sam...
# ds2.1.1:87.1         Katamāni tasmiṁ samaye aṭṭhindriyāni honti?
# ds2.1.1:86.4                 Ime tasmiṁ samaye tayo āhārā honti.
# ds2.1.1:86.3                ayaṁ tasmiṁ samaye viññāṇāhāro hoti.
# ...                                                           ...
# pt2.11:157.1    Upādānasampayuttaṁ dhammaṁ saṁsaṭṭho upādānasa...
# pt2.11:157.0.2                      2.11.3.5.1–4 Paccayānulomādi
# pt2.11:157.0.1                           2.11.3.5. Saṁsaṭṭhavāra
# pt2.11:175.1    Upādānavippayutto dhammo upādānasampayuttassa ...
# pt1.13:218.1    Paritto ca appamāṇo ca dhammā appamāṇassa dham...
#
# [88414 rows x 4 columns]

# %% [markdown]
# #### Abhidhamma Index

# %%
ds_root=Path('../pali_cannon/abhidhamma/ds')

chapter_dict = {}

ds_index = {}


for file_path in ds_root.rglob("*.json"):
    relative_path = file_path.relative_to(root)
    parts = relative_path.parts
    *folders, filename = parts

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

        if folders[1] == 'ds1':
            chapter_value = list(data.values())[1].strip()
            chapter_key = list(data.keys())[2].split(":")[0]
        
        else:
            chapter_key = list(data.keys())[1].split(":")[0].rsplit(".", 1)[0]
            chapter_value = list(data.values())[2].strip().split(" ", 1)[1]
            



        chapter_dict[chapter_key] = chapter_value

chapter_dict = dict(natsorted(chapter_dict.items()))



# ds_index['dt1.Matika'] = {k: v for k, v in chapter_dict.items() if k.split('.')[0]=='ds1'}
# ds_index['dt2.Niddesa'] = {k: v for k, v in chapter_dict.items() if k.split('.')[0]=='ds2'}

# ds_index


chapter_dict
# Out:
# {'ds1.1': 'Tikamātikā',
#  'ds1.2': 'Dukamātikā',
#  'ds1.3': 'Suttantikadukamātikā',
#  'ds2.1': 'Cittuppādakaṇḍa',
#  'ds2.2': 'Rūpakaṇḍa',
#  'ds2.3': 'Nikkhepakaṇḍa',
#  'ds2.4': 'Aṭṭhakathākaṇḍa'}

# %%
# Vibhanga

VB_root=Path('../pali_cannon/abhidhamma/vb/')

vb_index = {}

for file_path in VB_root.rglob("*.json"):

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)


        chapter = list(data.values())[1].strip()
        chapter_id = list(data.keys())[1].split(":")[0]

        vb_index[chapter_id] = chapter

sorted_dict = {k: vb_index[k] for k in natsorted(vb_index)}

vb_index = sorted_dict

# %%
#Dhatukatha index - PERFECTED
dt_root=Path('../pali_cannon/abhidhamma/dt/')

chapter_dict = {}
dt_index = {}


for file_path in dt_root.rglob("*.json"):
    relative_path = file_path.relative_to(root)
    parts = relative_path.parts
    *folders, filename = parts

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

        chapter_value = list(data.values())[2].strip().split(" ", 1)[1]
        chapter_key = list(data.keys())[2].split(":")[0]

        chapter_dict[chapter_key] = chapter_value

chapter_dict = dict(natsorted(chapter_dict.items()))



dt_index['dt1.Uddesa'] = {k: v for k, v in chapter_dict.items() if k.split('.')[0]=='dt1'}
dt_index['dt2.Niddesa'] = {k: v for k, v in chapter_dict.items() if k.split('.')[0]=='dt2'}

dt_index
# Out:
# {'dt1.Uddesa': {'dt1.1': 'Nayamātikā',
#   'dt1.2': 'Abbhantaramātikā',
#   'dt1.3': 'Nayamukhamātikā',
#   'dt1.4': 'Lakkhaṇamātikā',
#   'dt1.5': 'Bāhiramātikā'},
#  'dt2.Niddesa': {'dt2.1': 'Paṭhamanaya saṅgahāsaṅgahapadaniddesa',
#   'dt2.2': 'Dutiyanaya Saṅgahitenaasaṅgahitapadaniddesa',
#   'dt2.3': 'Tatiyanaya Asaṅgahitenasaṅgahitapadaniddesa',
#   'dt2.4': 'Catutthanaya Saṅgahitenasaṅgahitapadaniddesa',
#   'dt2.5': 'Pañcamanaya Asaṅgahitenaasaṅgahitapadaniddesa',
#   'dt2.6': 'Chaṭṭhanaya Sampayogavippayogapadaniddesa',
#   'dt2.7': 'Sattamanaya Sampayuttenavippayuttapadaniddesa',
#   'dt2.8': 'Aṭṭhamanaya Vippayuttenasampayuttapadaniddesa',
#   'dt2.9': 'Navamanaya Sampayuttenasampayuttapadaniddesa',
#   'dt2.10': 'Dasamanaya Vippayuttenavippayuttapadaniddesa',
#   'dt2.11': 'Ekādasamanaya Saṅgahitenasampayuttavippayuttapadaniddesa',
#   'dt2.12': 'Dvādasamanaya Sampayuttenasaṅgahitāsaṅgahitapadaniddesa',
#   'dt2.13': 'Terasamanaya Asaṅgahitenasampayuttavippayuttapadaniddesa',
#   'dt2.14': 'Cuddasamanaya Vippayuttenasaṅgahitāsaṅgahitapadaniddesa'}}

# %%
#Kathavatthu Index Creation - PERFECTED
ya_root=Path('../pali_cannon/abhidhamma/kv/')

chapter_dict={}
kv_index={}

#eg: file_path = ..pali_cannon/abhidhamma/kv/kv2/kv2.2_root-pli-ms.json
for file_path in ya_root.rglob("*.json"):
    relative_path = file_path.relative_to(root)
    parts = relative_path.parts

    #eg: filename = kv2.2_root-pli-ms.json
    #eg: folders = ['kv', 'kv2']
    *folders, filename = parts
    
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)      
        #Values or text level - reading unit - one higher than verse level 
        #In Abhidhamma pitaka this level corresponds to individual JSON files
        #get value and lowest key of the dictionary
        chapter_key = list(data.keys())[3].split(":")[0]
        chapter_value = list(data.values())[3].strip()
        chapter_dict[chapter_key] = chapter_value

        vagga_key = list(data.keys())[2].split(".")[0]
        vagga_value = list(data.values())[2].strip()
        vagga_key = f"{vagga_key}.{vagga_value}"
        kv_index[vagga_key] = 'chapter_dict'

       

    
    chapter_dict = dict(natsorted(chapter_dict.items()))
    kv_index = dict(natsorted(vagga_dict.items()))
    #kv_index = dict(natsorted(kv_index.items()))

#select sub-dict from chapter_dict and insert to vagga_dict
for k,v in kv_index.items():
     sub_key = k.split('.')[0]
     kv_index[k] = {k: v for k, v in chapter_dict.items() if k.split('.')[0]==(sub_key)}

kv_index
# Out:
# {'kv1.Paṭhamavagga': {'kv1.1': 'Puggalakathā',
#   'kv1.2': 'Parihānikathā',
#   'kv1.3': 'Brahmacariyakathā',
#   'kv1.4': 'Odhisokathā',
#   'kv1.5': 'Jahatikathā',
#   'kv1.6': 'Sabbamatthītikathā',
#   'kv1.7': 'Atītakkhandhādikathā',
#   'kv1.8': 'Ekaccaṁatthītikathā',
#   'kv1.9': 'Satipaṭṭhānakathā',
#   'kv1.10': 'Hevatthikathā'},
#  'kv2.Dutiyavagga': {'kv2.1': 'Parūpahārakathā',
#   'kv2.2': 'Aññāṇakathā',
#   'kv2.3': 'Kaṅkhākathā',
#   'kv2.4': 'Paravitāraṇakathā',
#   'kv2.5': 'Vacībhedakathā',
#   'kv2.6': 'Dukkhāhārakathā',
#   'kv2.7': 'Cittaṭṭhitikathā',
#   'kv2.8': 'Kukkuḷakathā',
#   'kv2.9': 'Anupubbābhisamayakathā',
#   'kv2.10': 'Vohārakathā',
#   'kv2.11': 'Nirodhakathā'},
#  'kv3.Tatiyavagga': {'kv3.1': 'Balakathā',
#   'kv3.2': 'Ariyantikathā',
#   'kv3.3': 'Vimuttikathā',
#   'kv3.4': 'Vimuccamānakathā',
#   'kv3.5': 'Aṭṭhamakakathā',
#   'kv3.6': 'Aṭṭhamakassaindriyakathā',
#   'kv3.7': 'Dibbacakkhukathā',
#   'kv3.8': 'Dibbasotakathā',
#   'kv3.9': 'Yathākammūpagatañāṇakathā',
#   'kv3.10': 'Saṁvarakathā',
#   'kv3.11': 'Asaññakathā',
#   'kv3.12': 'Nevasaññānāsaññāyatanakathā'},
#  'kv4.Catutthavagga': {'kv4.1': 'Gihissaarahātikathā',
#   'kv4.2': 'Upapattikathā',
#   'kv4.3': 'Anāsavakathā',
#   'kv4.4': 'Samannāgatakathā',
#   'kv4.5': 'Upekkhāsamannāgatakathā',
#   'kv4.6': 'Bodhiyābuddhotikathā',
#   'kv4.7': 'Lakkhaṇakathā',
#   'kv4.8': 'Niyāmokkantikathā',
#   'kv4.9': 'Aparāpisamannāgatakathā',
#   'kv4.10': 'Sabbasaṁyojanappahānakathā'},
#  'kv5.Pañcamavagga': {'kv5.1': 'Vimuttikathā',
#   'kv5.2': 'Asekhañāṇakathā',
#   'kv5.3': 'Viparītakathā',
#   'kv5.4': 'Niyāmakathā',
#   'kv5.5': 'Paṭisambhidākathā',
#   'kv5.6': 'Sammutiñāṇakathā',
#   'kv5.7': 'Cittārammaṇakathā',
#   'kv5.8': 'Anāgatañāṇakathā',
#   'kv5.9': 'Paṭuppannañāṇakathā',
#   'kv5.10': 'Phalañāṇakathā'},
#  'kv6.Chaṭṭhavagga': {'kv6.1': 'Niyāmakathā',
#   'kv6.2': 'Paṭiccasamuppādakathā',
#   'kv6.3': 'Saccakathā',
#   'kv6.4': 'Āruppakathā',
#   'kv6.5': 'Nirodhasamāpattikathā',
#   'kv6.6': 'Ākāsakathā',
#   'kv6.7': 'Ākāsosanidassanotikathā',
#   'kv6.8': 'Pathavīdhātusanidassanātiādikathā',
#   'kv6.9': 'Cakkhundriyaṁsanidassanantiādikathā',
#   'kv6.10': 'Kāyakammaṁsanidassanantikathā'},
#  'kv7.Sattamavagga': {'kv7.1': 'Saṅgahitakathā',
#   'kv7.2': 'Sampayuttakathā',
#   'kv7.3': 'Cetasikakathā',
#   'kv7.4': 'Dānakathā',
#   'kv7.5': 'Paribhogamayapuññakathā',
#   'kv7.6': 'Itodinnakathā',
#   'kv7.7': 'Pathavīkammavipākotikathā',
#   'kv7.8': 'Jarāmaraṇaṁvipākotikathā',
#   'kv7.9': 'Ariyadhammavipākakathā',
#   'kv7.10': 'Vipākovipākadhammadhammotikathā'},
#  'kv8.Aṭṭhamavagga': {'kv8.1': 'Chagatikathā',
#   'kv8.2': 'Antarābhavakathā',
#   'kv8.3': 'Kāmaguṇakathā',
#   'kv8.4': 'Kāmakathā',
#   'kv8.5': 'Rūpadhātukathā',
#   'kv8.6': 'Arūpadhātukathā',
#   'kv8.7': 'Rūpadhātuyāāyatanakathā',
#   'kv8.8': 'Arūperūpakathā',
#   'kv8.9': 'Rūpaṅkammantikathā',
#   'kv8.10': 'Jīvitindriyakathā',
#   'kv8.11': 'Kammahetukathā'},
#  'kv9.Navamavagga': {'kv9.1': 'Ānisaṁsadassāvīkathā',
#   'kv9.2': 'Amatārammaṇakathā',
#   'kv9.3': 'Rūpaṁsārammaṇantikathā',
#   'kv9.4': 'Anusayāanārammaṇātikathā',
#   'kv9.5': 'Ñāṇaṁanārammaṇantikathā',
#   'kv9.6': 'Atītānāgatārammaṇakathā',
#   'kv9.7': 'Vitakkānupatitakathā',
#   'kv9.8': 'Vitakkavipphārasaddakathā',
#   'kv9.9': 'Nayathācittassavācātikathā',
#   'kv9.10': 'Nayathācittassakāyakammantikathā',
#   'kv9.11': 'Atītānāgatasamannāgatakathā'},
#  'kv10.Dasamavagga': {'kv10.1': 'Nirodhakathā',
#   'kv10.2': 'Rūpaṁmaggotikathā',
#   'kv10.3': 'Pañcaviññāṇasamaṅgissamaggakathā',
#   'kv10.4': 'Pañcaviññāṇākusalāpiakusalāpītikathā',
#   'kv10.5': 'Sābhogātikathā',
#   'kv10.6': 'Dvīhisīlehikathā',
#   'kv10.7': 'Sīlaṁacetasikantikathā',
#   'kv10.8': 'Sīlaṁnacittānuparivattītikathā',
#   'kv10.9': 'Samādānahetukathā',
#   'kv10.10': 'Viññattisīlantikathā',
#   'kv10.11': 'Aviññattidussilyantikathā'},
#  'kv11.Ekādasamavagga': {'kv11.1': 'Tissopianusayakathā',
#   'kv11.2': 'Ñāṇakathā',
#   'kv11.3': 'Ñāṇaṁcittavippayuttantikathā',
#   'kv11.4': 'Idaṁdukkhantikathā',
#   'kv11.5': 'Iddhibalakathā',
#   'kv11.6': 'Samādhikathā',
#   'kv11.7': 'Dhammaṭṭhitatākathā',
#   'kv11.8': 'Aniccatākathā'},
#  'kv12.Dvādasamavagga': {'kv12.1': 'Saṁvarokammantikathā',
#   'kv12.2': 'Kammakathā',
#   'kv12.3': 'Saddovipākotikathā',
#   'kv12.4': 'Saḷāyatanakathā',
#   'kv12.5': 'Sattakkhattuparamakathā',
#   'kv12.6': 'Kolaṅkolakathā',
#   'kv12.7': 'Ekabījīkathā',
#   'kv12.8': 'Jīvitāvoropanakathā',
#   'kv12.9': 'Duggatikathā',
#   'kv12.10': 'Sattamabhavikakathā'},
#  'kv13.Terasamavagga': {'kv13.1': 'Kappaṭṭhakathā',
#   'kv13.2': 'Kusalapaṭilābhakathā',
#   'kv13.3': 'Anantarāpayuttakathā',
#   'kv13.4': 'Niyatassaniyāmakathā',
#   'kv13.5': 'Nivutakathā',
#   'kv13.6': 'Sammukhībhūtakathā',
#   'kv13.7': 'Samāpannoassādetikathā',
#   'kv13.8': 'Asātarāgakathā',
#   'kv13.9': 'Dhammataṇhāabyākatātikathā',
#   'kv13.10': 'Dhammataṇhānadukkhasamudayotikathā'},
#  'kv14.Cuddasamavagga': {'kv14.1': 'Kusalākusalapaṭisandahanakathā',
#   'kv14.2': 'Saḷāyatanuppattikathā',
#   'kv14.3': 'Anantarapaccayakathā',
#   'kv14.4': 'Ariyarūpakathā',
#   'kv14.5': 'Aññoanusayotikathā',
#   'kv14.6': 'Pariyuṭṭhānaṁcittavippayuttantikathā',
#   'kv14.7': 'Pariyāpannakathā',
#   'kv14.8': 'Abyākatakathā',
#   'kv14.9': 'Apariyāpannakathā'},
#  'kv15.Pannarasamavagga': {'kv15.1': 'Paccayatākathā',
#   'kv15.2': 'Aññamaññapaccayakathā',
#   'kv15.3': 'Addhākathā',
#   'kv15.4': 'Khaṇalayamuhuttakathā',
#   'kv15.5': 'Āsavakathā',
#   'kv15.6': 'Jarāmaraṇakathā',
#   'kv15.7': 'Saññāvedayitakathā',
#   'kv15.8': 'Dutiyasaññāvedayitakathā',
#   'kv15.9': 'Tatiyasaññāvedayitakathā',
#   'kv15.10': 'Asaññasattupikakathā',
#   'kv15.11': 'Kammūpacayakathā'},
#  'kv16.Soḷasamavagga': {'kv16.1': 'Niggahakathā',
#   'kv16.2': 'Paggahakathā',
#   'kv16.3': 'Sukhānuppadānakathā',
#   'kv16.4': 'Adhigayhamanasikārakathā',
#   'kv16.5': 'Rūpaṁhetūtikathā',
#   'kv16.6': 'Rūpaṁsahetukantikathā',
#   'kv16.7': 'Rūpaṅkusalākusalantikathā',
#   'kv16.8': 'Rūpaṁvipākotikathā',
#   'kv16.9': 'Rūpaṁrūpāvacarārūpāvacarantikathā',
#   'kv16.10': 'Rūpārūpadhātupariyāpannakathā'},
#  'kv17.Sattarasamavagga': {'kv17.1': 'Atthiarahatopuññūpacayotikathā',
#   'kv17.2': 'Natthiarahatoakālamaccūtikathā',
#   'kv17.3': 'Sabbamidaṅkammatotikathā',
#   'kv17.4': 'Indriyabaddhakathā',
#   'kv17.5': 'Ṭhapetvāariyamaggantikathā',
#   'kv17.6': 'Navattabbaṁsaṅghodakkhiṇaṁpaṭiggaṇhātikathā',
#   'kv17.7': 'Navattabbaṁsaṅghodakkhiṇaṁvisodhetītikathā',
#   'kv17.8': 'Navattabbaṁsaṅghobhuñjatītikathā',
#   'kv17.9': 'Navattabbaṁsaṅghassadinnaṁmahapphalantikathā',
#   'kv17.10': 'Navattabbaṁbuddhassadinnaṁmahapphalantikathā',
#   'kv17.11': 'Dakkhiṇāvisuddhikathā'},
#  'kv18.Aṭṭhārasamavagga': {'kv18.1': 'Manussalokakathā',
#   'kv18.2': 'Dhammadesanākathā',
#   'kv18.3': 'Karuṇākathā',
#   'kv18.4': 'Gandhajātikathā',
#   'kv18.5': 'Ekamaggakathā',
#   'kv18.6': 'Jhānasaṅkantikathā',
#   'kv18.7': 'Jhānantarikakathā',
#   'kv18.8': 'Saddaṁsuṇātītikathā',
#   'kv18.9': 'Cakkhunārūpaṁpassatītikathā'},
#  'kv19.Ekūnavīsatimavagga': {'kv19.1': 'Kilesajahanakathā',
#   'kv19.2': 'Suññatākathā',
#   'kv19.3': 'Sāmaññaphalakathā',
#   'kv19.4': 'Pattikathā',
#   'kv19.5': 'Tathatākathā',
#   'kv19.6': 'Kusalakathā',
#   'kv19.7': 'Accantaniyāmakathā',
#   'kv19.8': 'Indriyakathā'},
#  'kv20.Vīsatimavagga': {'kv20.1': 'Asañciccakathā',
#   'kv20.2': 'Ñāṇakathā',
#   'kv20.3': 'Nirayapālakathā',
#   'kv20.4': 'Tiracchānakathā',
#   'kv20.5': 'Maggakathā',
#   'kv20.6': 'Ñāṇakathā'},
#  'kv21.Ekavīsatimavagga': {'kv21.1': 'Sāsanakathā',
#   'kv21.2': 'Avivittakathā',
#   'kv21.3': 'Saṁyojanakathā',
#   'kv21.4': 'Iddhikathā',
#   'kv21.5': 'Buddhakathā',
#   'kv21.6': 'Sabbadisākathā',
#   'kv21.7': 'Dhammakathā',
#   'kv21.8': 'Kammakathā'},
#  'kv22.Bāvīsatimavagga': {'kv22.1': 'Parinibbānakathā',
#   'kv22.2': 'Kusalacittakathā',
#   'kv22.3': 'Āneñjakathā',
#   'kv22.4': 'Dhammābhisamayakathā',
#   'kv22.5': 'Tissopikathā',
#   'kv22.6': 'Abyākatakathā',
#   'kv22.7': 'Āsevanapaccayakathā',
#   'kv22.8': 'Khaṇikakathā'},
#  'kv23.Tevīsatimavagga': {'kv23.1': 'Ekādhippāyakathā',
#   'kv23.2': 'Arahantavaṇṇakathā',
#   'kv23.3': 'Issariyakāmakārikādikathā',
#   'kv23.4': 'Patirūpakathā',
#   'kv23.5': 'Aparinipphannakathā'}}

# %%
#puggalapannatti
pp_root=Path('../pali_cannon/abhidhamma/pp/')

pp_index = {}
matika_index = {}
niddesa_index = {}

for file_path in pp_root.rglob("*.json"):
    relative_path = file_path.relative_to(root)
    parts = relative_path.parts
    *folders, filename = parts

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

        if folders[1] == 'pp1':

            chapter = list(data.values())[2].strip().split(" ", 1)[1]
            chapter_id = list(data.keys())[2].split(":")[0]

            matika_index[chapter_id] = chapter      

        elif folders[1] == 'pp2':

            chapter = list(data.values())[2].strip().split(" ", 1)[1]
            chapter_id = list(data.keys())[2].split(":")[0]

            niddesa_index[chapter_id] = chapter

        matika_index_sorted = {k: matika_index[k] for k in natsorted(matika_index)}
        niddesa_index_sorted = {k: niddesa_index[k] for k in natsorted(niddesa_index)}



pp_index = {"Mātikā": matika_index_sorted, 
            "Niddesa": niddesa_index_sorted
}

pp_index
# Out:
# {'Mātikā': {'pp1.1': 'Ekakauddesa',
#   'pp1.2': 'Dukauddesa',
#   'pp1.3': 'Tikauddesa',
#   'pp1.4': 'Catukkauddesa',
#   'pp1.5': 'Pañcakauddesa',
#   'pp1.6': 'Chakkauddesa',
#   'pp1.7': 'Sattakauddesa',
#   'pp1.8': 'Aṭṭhakauddesa',
#   'pp1.9': 'Navakauddesa',
#   'pp1.10': 'Dasakauddesa'},
#  'Niddesa': {'pp2.1': 'Ekakapuggalapaññatti',
#   'pp2.2': 'Dukapuggalapaññatti',
#   'pp2.3': 'Tikapuggalapaññatti',
#   'pp2.4': 'Catukkapuggalapaññatti',
#   'pp2.5': 'Pañcakapuggalapaññatti',
#   'pp2.6': 'Chakkapuggalapaññatti',
#   'pp2.7': 'Sattakapuggalapaññatti',
#   'pp2.8': 'Aṭṭhakapuggalapaññatti',
#   'pp2.9': 'Navakapuggalapaññatti',
#   'pp2.10': 'Dasakapuggalapaññatti'}}

# %%
#Yamaka Index Creation - PERFECTED
ya_root=Path('../pali_cannon/abhidhamma/ya/')

ya_index = {}
chapter_dict={}
yamaka_dict={}
#eg: file_path = ../pali_cannon/abhidhamma/ya/ya2/ya2.2.2_root-pli-ms.json
for file_path in ya_root.rglob("*.json"):
    relative_path = file_path.relative_to(root)
    parts = relative_path.parts

    #eg: filename = ya2.2.2_root-pli-ms.json
    #eg: folders = ['ya', 'ya2']
    *folders, filename = parts
    
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)      
        #Values or text level - reading unit - one higher than verse level 
        #In Abhidhamma pitaka this level corresponds to individual JSON files
        #get value and lowest key of the dictionary
        filename_key = filename.split("_")[0]
        

        #JSON files are less deep both chapter level and text level are identical
        if len(filename.split(".")) == 3:
            filename_value = list(data.values())[1].strip().split(" ")[1]
            #chapter key eg:  "ya4.3:0.2": "4.3. Pariññāvāra "  -> Pavattivāra is chapter name
            #get 2nd value of JSON, strip whitespace and split by space
            chapter_value = list(data.values())[1].strip().split(" ")[1]
            chapter_key = list(data.keys())[1].split(":")[0]
            #join the list with a period and add "ya" prefix
            chapter_key =  f"{chapter_key}.{chapter_value}"

        else:
            filename_value = list(data.values())[2].strip().split(" ")[1]
            #chapter key eg:  "ya2.2.2:0.2": "2.2 Pavattivāra"  -> Pavattivāra is chapter name
            #get 2nd value of JSON, strip whitespace and split by space
            chapter_key = list(data.values())[1].strip().split(" ")
            #join the list with a period and add "ya" prefix
            chapter_key =  f"ya{'.'.join(chapter_key)}"

            #get the value of the highest key of the dict for YAMAKA PAKARANA
            yamaka_value = list(data.values())[0].strip().split(" ")[1]
            yamaka_key = folders[1]
            yamaka_key = f"{yamaka_key}.{yamaka_value}"
     
        #chapter_dict is a dictionary of chapter names (Hetuvārādiniddesa, Uppādavāra) and their corresponding nested dict
        chapter_dict[filename_key] = filename_value
        #yamaka_dict is a dictionary of yamaka names (eg: Uddesa, Niddesa, etc) and their corresponding nested dict
        yamaka_dict[chapter_key] = 'chapter_dict'
        #ya_index is a dictionary of the 10 yamakas names (eg: Mūlayamaka) and their corresponding nested dict
        ya_index[yamaka_key] = 'yamaka_dict'
       

    
    chapter_dict = dict(natsorted(chapter_dict.items()))
    yamaka_dict = dict(natsorted(yamaka_dict.items()))
    ya_index = dict(natsorted(ya_index.items()))


#select sub-dict from chapter_dict and insert to yamaka_dict
for k,v in yamaka_dict.items():
    sub_key = k.rpartition('.')[0]
    yamaka_dict[k] = {k: v for k, v in chapter_dict.items() if k.rpartition('.')[0]==(sub_key)}


#select sub-dict from yamaka_dict and insert to ya_index
for k,v in ya_index.items():
    sub_key = k.split('.')[0]
    ya_index[k] = {k: v for k, v in yamaka_dict.items() if k.split('.')[0]==(sub_key)}

#ya_index

# %%
#puggalapannatti
pt_root=Path('../pali_cannon/abhidhamma/patthana/')

chapter_dict={}

for file_path in pt_root.rglob("*.json"):
    relative_path = file_path.relative_to(root)
    parts = relative_path.parts
    *folders, filename = parts

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        
        chapter_key = list(data.values())[2].strip().split(" ", 1)[0]
        chapter_value = list(data.values())[2].strip().split(" ", 1)[1]
        chapter_key = f"pt{chapter_key}"

        chapter_dict[chapter_key] = chapter_value

chapter_dict = dict(natsorted(chapter_dict.items()))

chapter_dict
# Out:
# {'pt1.1.': 'Nikkhepavāra',
#  'pt1.2.': 'Kusalattika',
#  'pt1.3.': 'Vedanāttika',
#  'pt1.4.': 'Vipākattika',
#  'pt1.5.': 'Upādinnattika',
#  'pt1.6.': 'Saṅkiliṭṭhattika',
#  'pt1.7.': 'Vitakkattika',
#  'pt1.8.': 'Pītittika',
#  'pt1.9.': 'Dassanenapahātabbattika',
#  'pt1.10.': 'Dassanenapahātabbahetukattika',
#  'pt1.11.': 'Ācayagāmittika',
#  'pt1.12.': 'Sekkhattika',
#  'pt1.13.': 'Parittattika',
#  'pt1.14.': 'Parittārammaṇattika',
#  'pt1.15.': 'Hīnattika',
#  'pt1.16.': 'Micchattaniyatattika',
#  'pt1.17.': 'Maggārammaṇattika',
#  'pt1.18.': 'Uppannattika',
#  'pt1.19.': 'Atītattika',
#  'pt1.20.': 'Atītārammaṇattika',
#  'pt1.21.': 'Ajjhattattika',
#  'pt1.22.': 'Ajjhattārammaṇattika',
#  'pt1.23.': 'Sanidassanasappaṭighattika',
#  'pt2.1.': 'Hetugocchaka',
#  'pt2.2.': 'Cūḷantaraduka',
#  'pt2.3.': 'Āsavagocchaka',
#  'pt2.4.': 'Saññojanagocchaka',
#  'pt2.5.': 'Ganthagocchaka',
#  'pt2.6–7.': 'Oghayogagocchaka',
#  'pt2.8.': 'Nīvaraṇagocchaka',
#  'pt2.9.': 'Parāmāsagocchaka',
#  'pt2.10.': 'Mahantaraduka',
#  'pt2.11.': 'Upādānagocchaka',
#  'pt2.12.': 'Kilesagocchaka',
#  'pt2.13.': 'Piṭṭhiduka',
#  'pt3.1.': 'Hetuduka, Tika',
#  'pt9.1.': 'Hetuduka, Kusalattika',
#  'pt9.2.': 'Hetuduka, Vedanāttika',
#  'pt9.3.': 'Hetuduka, Vipākattikādi',
#  'pt9.4.': 'Hetuduka, Ācayagāmattikādi',
#  'pt9.5.': 'Hetuduka, Sanidassanattika',
#  'pt9.6.': 'Sahetukadukādi, Kusalattika',
#  'pt9.7.': 'Hetusahetukadukādi, Kusalattika',
#  'pt9.8.': 'Nahetusahetukaduka, Kusalattika',
#  'pt9.9.': 'Cūḷantaraduka, Kusalattika',
#  'pt9.10.': 'Āsavagocchaka, Kusalattika',
#  'pt9.11.': 'Chagocchaka, Kusalattika',
#  'pt9.12.': 'Mahantaraduka, Kusalattika',
#  'pt9.13.': 'Upādānagocchaka, Kusalattika',
#  'pt9.14.': 'Kilesagocchaka, Kusalattika',
#  'pt9.15.': 'Piṭṭhiduka, Kusalattika',
#  'pt9.16.': 'Saraṇaduka, Vedanāttikādi',
#  'pt9.17.': 'Saraṇaduka, Sanidassanattika',
#  'pt10.1.': 'Kusalattika, Hetuduka',
#  'pt10.2.': 'Kusalattika, Sahetukaduka',
#  'pt10.3.': 'Kusalattika, Hetusampayuttadukādi',
#  'pt10.4.': 'Kusalattika, Cūḷantaraduka',
#  'pt10.5.': 'Kusalattika, Āsavagocchaka',
#  'pt10.6.': 'Kusalattika, Saññojanagocchakādi',
#  'pt10.7.': 'Kusalattika, Mahantaraduka',
#  'pt10.8.': 'Kusalattika, Upādānadukādi',
#  'pt10.9.': 'Kusalattika, Piṭṭhiduka',
#  'pt10.10.': 'Vedanāttika, Hetuduka',
#  'pt10.11.': 'Vipākattikādi, Hetuduka',
#  'pt10.12.': 'Sanidassanattika, Hetudukādi',
#  'pt10.13.': 'Sanidassanattika, Cūḷantaraduka',
#  'pt10.14.': 'Sanidassanattika, Āsavāsavagocchakādi',
#  'pt10.15.': 'Sanidassanattika, Mahantaraduka',
#  'pt10.16.': 'Sanidassanattika, Upādānadukādi',
#  'pt10.17.': 'Sanidassanattika, Piṭṭhiduka',
#  'pt11.1.': 'Kusalattika, Vedanāttika',
#  'pt11.2.': 'Kusalattika, Vipākattika',
#  'pt11.3.': 'Kusalattika, Upādinnattika',
#  'pt11.4.': 'Kusalattika, Saṅkiliṭṭhattika',
#  'pt11.5.': 'Kusalattika, Vitakkattika',
#  'pt11.6.': 'Kusalattika, Pītittika',
#  'pt11.7.': 'Kusalattika, Dassanattikādi',
#  'pt11.8.': 'Kusalattika, Hīnattikādi',
#  'pt11.9.': 'Kusalattika, Sanidassanattika',
#  'pt11.10.': 'Vedanāttika, Kusalattika',
#  'pt11.11.': 'Vedanāttika, Vipākattika',
#  'pt11.12.': 'Vipākattika, Kusalattika',
#  'pt11.13.': 'Upādinnattika, Kusalattika',
#  'pt11.14.': 'Saṅkiliṭṭhattika, Kusalattika',
#  'pt11.15.': 'Vitakkattikādi, Kusalattika',
#  'pt11.16.': 'Sanidassanattika, Kusalattika',
#  'pt11.17.': 'Sanidassanattika, Vedanāttikādi',
#  'pt12.1.': 'Hetuduka, Sahetukadukādi',
#  'pt16.94.': 'Sanidassanattika, Sauttaraduka',
#  'pt16.95.': 'Sanidassanattika, Saraṇaduka',
#  'pt17.1.': 'Kusalattika, Vedanāttika',
#  'pt17.2.': 'Kusalattika, Vipākattika',
#  'pt17.3.': 'Kusalattika, Upādinnattika',
#  'pt17.4.': 'Kusalattika, Saṅkiliṭṭhattika',
#  'pt17.5.': 'Kusalattika, Vitakkattika',
#  'pt17.6.': 'Kusalattika, Pītittika',
#  'pt17.7.': 'Kusalattika, Dassanattika',
#  'pt17.8.': 'Kusalattika, Dassanahetuttika',
#  'pt17.9.': 'Kusalattika, Ācayagāmittika',
#  'pt17.10.': 'Kusalattika, Sekkhattika',
#  'pt17.11.': 'Kusalattika, Parittattika',
#  'pt17.12.': 'Kusalattika, Parittārammaṇattika',
#  'pt17.13.': 'Kusalattika, Hīnattika',
#  'pt17.14.': 'Kusalattika, Micchattaniyatattika',
#  'pt17.15.': 'Kusalattika, Maggārammaṇattika',
#  'pt17.16.': 'Kusalattika, Uppannattika',
#  'pt17.17.': 'Kusalattika, Atītattika',
#  'pt17.18.': 'Kusalattika, Atītārammaṇattika',
#  'pt17.19.': 'Kusalattika, Ajjhattattikadvaya',
#  'pt17.20.': 'Kusalattika, Sanidassanattika',
#  'pt17.21.': 'Vedanāttika, Kusalattika',
#  'pt17.22.': 'Vipākattika, Kusalattika',
#  'pt17.23.': 'Upādinnattika, Kusalattika',
#  'pt17.24.': 'Saṅkiliṭṭhattika, Kusalattika',
#  'pt17.25.': 'Vitakkattika, Kusalattika',
#  'pt17.26.': 'Pītittika, Kusalattika',
#  'pt17.27.': 'Sanidassanattika, Kusalattika',
#  'pt17.28.': 'Sanidassanattika, Vedanāttika',
#  'pt17.29.': 'Sanidassanattika, Vipākattika',
#  'pt17.30.': 'Sanidassanattika, Upādinnattika',
#  'pt17.31.': 'Sanidassanattika, Saṅkiliṭṭhattika',
#  'pt17.32.': 'Sanidassanattika, Vitakkattikādi',
#  'pt17.33.': 'Sanidassanattika, Ajjhattārammaṇattika',
#  'pt18.1.': 'Hetuduka, Sahetukaduka',
#  'pt18.2.': 'Hetuduka, Hetusampayuttaduka',
#  'pt18.3.': 'Hetuduka, Hetusahetukadukādi',
#  'pt18.4.': 'Hetuduka, Cūḷantaraduka',
#  'pt18.5.': 'Hetuduka, Āsavagocchaka',
#  'pt18.6.': 'Hetuduka, Saññojanagocchakādi',
#  'pt18.7.': 'Hetuduka, Mahantaradukādi',
#  'pt18.8.': 'Hetuduka, Dassanenapahātabbadukādi',
#  'pt18.9.': 'Hetuduka, Saraṇaduka',
#  'pt18.10.': 'Sahetukaduka, Hetuduka',
#  'pt18.11.': 'Hetusampayuttaduka, Hetuduka',
#  'pt18.12.': 'Hetusahetukaduka, Hetuduka',
#  'pt18.13.': 'Hetuhetusampayuttaduka, Hetuduka',
#  'pt18.14.': 'Cūḷantaraduka, Hetuduka',
#  'pt18.15.': 'Āsavaduka, Hetuduka',
#  'pt18.16.': 'Sāsavaduka, Hetuduka',
#  'pt18.17.': 'Āsavasampayuttaduka, Hetuduka',
#  'pt18.18.': 'Āsavasāsavaduka, Hetuduka',
#  'pt18.19.': 'Āsavaāsavasampayuttaduka, Hetuduka',
#  'pt18.20.': 'Āsavavippayuttasāsavaduka, Hetuduka',
#  'pt18.21.': 'Saññojanagocchakādi, Hetuduka',
#  'pt18.22.': 'Mahantaraduka, Hetuduka',
#  'pt18.23.': 'Upādānagocchakādi, Hetuduka',
#  'pt18.24.': 'Piṭṭhiduka, Hetuduka',
#  'pt18.25.': 'Saraṇaduka, Hetudukādi',
#  'pt18.26.': 'Saraṇaduka, Cūḷantaraduka',
#  'pt18.27.': 'Saraṇaduka, Āsavagocchakādi',
#  'pt18.28.': 'Saraṇaduka, Mahantaradukādi',
#  'pt18.29.': 'Saraṇaduka, Dassanenapahātabbadukādi',
#  'pt19.1.': 'Kusalattika',
#  'pt19.2.': 'Vedanāttika',
#  'pt19.3.': 'Vipākattika',
#  'pt19.4.': 'Upādinnattika',
#  'pt19.5.': 'Saṅkiliṭṭhattika',
#  'pt19.6.': 'Vitakkattika',
#  'pt19.7.': 'Pītittika',
#  'pt19.8.': 'Dassanattika',
#  'pt19.9.': 'Dassanahetuttika',
#  'pt19.10.': 'Ācayagāmittika',
#  'pt19.11.': 'Sekkhattika',
#  'pt19.12.': 'Parittattikādi',
#  'pt19.13.': 'Uppannattika',
#  'pt19.14.': 'Atītattikadvaya',
#  'pt19.15.': 'Ajjhattattikadvaya',
#  'pt19.16.': 'Sanidassanattika',
#  'pt20.1.': 'Hetugocchaka',
#  'pt20.2.': 'Cūḷantaraduka',
#  'pt20.3.': 'Āsavagocchaka',
#  'pt20.4.': 'Saññojanādichagocchaka',
#  'pt20.5.': 'Mahantaraduka',
#  'pt20.6.': 'Upādānagocchaka',
#  'pt20.7.': 'Kilesagocchaka',
#  'pt20.8.': 'Piṭṭhiduka',
#  'pt20.9.': 'Saraṇaduka',
#  'pt21.1.': 'Hetuduka, Kusalattika',
#  'pt21.2.': 'Sahetukadukādi, Kusalattika',
#  'pt21.3.': 'Hetuhetusampayuttaduka, Kusalattika',
#  'pt21.4.': 'Nahetusahetukaduka, Kusalattika',
#  'pt21.5.': 'Cūḷantaraduka, Kusalattika',
#  'pt21.6.': 'Āsavaduka, Kusalattika',
#  'pt21.7.': 'Sāsavaduka, Kusalattika',
#  'pt21.8.': 'Āsavasampayuttaduka, Kusalattika',
#  'pt21.9.': 'Āsavasāsavaduka, Kusalattika',
#  'pt21.10.': 'Āsavaāsavasampayuttaduka, Kusalattika',
#  'pt21.11.': 'Āsavavippayuttasāsavaduka, Kusalattika',
#  'pt21.12.': 'Saññojanādichagocchaka, Kusalattika',
#  'pt21.13.': 'Mahantaraduka, Kusalattika',
#  'pt21.14.': 'Upādānadukādi, Kusalattika',
#  'pt21.15.': 'Kilesadukādi, Kusalattika',
#  'pt21.16.': 'Piṭṭhiduka, Kusalattika',
#  'pt21.17.': 'Hetuduka, Vedanāttika',
#  'pt21.18.': 'Hetuduka, Vipākattika',
#  'pt21.19.': 'Hetuduka, Upādinnattika',
#  'pt22.16.': 'Kusalattika, Saraṇaduka',
#  'pt22.17.': 'Vedanāttika, Hetuduka',
#  'pt22.18.': 'Vipākattika, Hetuduka',
#  'pt22.19.': 'Upādinnattika, Hetuduka',
#  'pt22.20.': 'Saṅkiliṭṭhattika, Hetuduka',
#  'pt22.21.': 'Vitakkattikādi, Hetuduka',
#  'pt22.22.': 'Parittattikadvaya, Hetuduka',
#  'pt22.23.': 'Hīnattikādi, Hetuduka',
#  'pt22.24.': 'Atītattikadvaya, Hetuduka',
#  'pt22.25.': 'Ajjhattattikadvaya, Hetuduka',
#  'pt22.26.': 'Sanidassanattika, Hetuduka',
#  'pt22.27.': 'Sanidassanattika, Sahetukaduka',
#  'pt22.28.': 'Sanidassanattika, Hetusampayuttadukādi',
#  'pt22.29.': 'Sanidassanattika, Cūḷantaraduka',
#  'pt22.30.': 'Sanidassanattika, Āsavagocchaka',
#  'pt22.31.': 'Sanidassanattika, Saññojanagocchakādi',
#  'pt22.32.': 'Sanidassanattika, Mahantaraduka',
#  'pt22.33.': 'Sanidassanattika, Upādānadukādi',
#  'pt22.34.': 'Sanidassanattika, Kilesadukādi',
#  'pt22.35.': 'Sanidassanattika, Dassanenapahātabbadukādi',
#  'pt22.36.': 'Sanidassanattika, Saraṇaduka',
#  'pt23.1.': 'Kusalattika, Vedanāttika',
#  'pt23.2.': 'Kusalattika, Vipākattika',
#  'pt23.3.': 'Kusalattika, Upādinnattika',
#  'pt23.4.': 'Kusalattika, Saṅkiliṭṭhattika',
#  'pt23.5.': 'Kusalattika, Vitakkattika',
#  'pt23.6.': 'Kusalattika, Pītittika',
#  'pt23.7.': 'Kusalattika, Dassanattika',
#  'pt23.8.': 'Kusalattika, Dassanahetuttika',
#  'pt23.9.': 'Kusalattika, Ācayagāmittika',
#  'pt23.10.': 'Kusalattika, Sekkhattika',
#  'pt23.11.': 'Kusalattika, Parittattika',
#  'pt23.12.': 'Kusalattika, Parittārammaṇattika',
#  'pt23.13.': 'Kusalattika, Hīnattika',
#  'pt23.14.': 'Kusalattika, Micchattaniyatattika',
#  'pt23.15.': 'Kusalattika, Maggārammaṇattika',
#  'pt23.16.': 'Kusalattika, Uppannattika',
#  'pt23.17.': 'Kusalattika, Atītattikadvaya',
#  'pt23.18.': 'Kusalattika, Ajjhattattikadvaya',
#  'pt23.19.': 'Kusalattika, Sanidassanattika',
#  'pt23.20.': 'Vedanāttika, Kusalattika',
#  'pt23.21.': 'Vipākattika, Kusalattika',
#  'pt23.22.': 'Upādinnattika, Kusalattika',
#  'pt23.23.': 'Saṅkiliṭṭhattika, Kusalattika',
#  'pt23.24.': 'Vitakkattika, Kusalattika',
#  'pt23.25.': 'Pītittika, Kusalattika',
#  'pt23.26.': 'Dassanattika, Kusalattika',
#  'pt23.27.': 'Dassanahetuttika, Kusalattika',
#  'pt23.28.': 'Ācayagāmittika, Kusalattika',
#  'pt23.29.': 'Sekkhattika, Kusalattika',
#  'pt23.30.': 'Parittattika, Kusalattika',
#  'pt23.31.': 'Parittārammaṇattika, Kusalattika',
#  'pt23.32.': 'Hīnattika, Kusalattika',
#  'pt23.33.': 'Micchattaniyatattika, Kusalattika',
#  'pt23.34.': 'Maggārammaṇattika, Kusalattika',
#  'pt23.35.': 'Uppannattikādi, Kusalattika',
#  'pt23.36.': 'Atītārammaṇattika, Kusalattika',
#  'pt23.37.': 'Ajjhattattika, Kusalattika',
#  'pt23.38.': 'Ajjhattārammaṇattika, Kusalattika',
#  'pt23.39.': 'Sanidassanattika, Kusalattika',
#  'pt23.40.': 'Sanidassanattika, Vedanāttika',
#  'pt23.41.': 'Sanidassanattika, Vipākattika',
#  'pt23.42.': 'Sanidassanattika, Upādinnattika',
#  'pt23.43.': 'Sanidassanattika, Saṅkiliṭṭhattika',
#  'pt23.44.': 'Sanidassanattika, Vitakkattika',
#  'pt23.45.': 'Sanidassanattika, Pītittika',
#  'pt23.46.': 'Sanidassanattika, Dassanattika',
#  'pt23.47.': 'Sanidassanattika, Dassanahetuttika',
#  'pt23.48.': 'Sanidassanattika, Ācayagāmittika',
#  'pt23.49.': 'Sanidassanattika, Sekkhattika',
#  'pt23.50.': 'Sanidassanattika, Parittattika',
#  'pt23.51.': 'Sanidassanattika, Parittārammaṇattika',
#  'pt23.52.': 'Sanidassanattika, Hīnattika',
#  'pt23.53.': 'Sanidassanattika, Micchattaniyatattika',
#  'pt23.54.': 'Sanidassanattika, Maggārammaṇattika',
#  'pt23.55.': 'Sanidassanattika, Uppannattika',
#  'pt23.56.': 'Sanidassanattika, Atītattika',
#  'pt23.57.': 'Sanidassanattika, Atītārammaṇattika',
#  'pt23.58.': 'Sanidassanattika, Ajjhattattikadvaya',
#  'pt24.1.': 'Hetuduka, Sahetukaduka',
#  'pt24.2.': 'Hetuduka, Hetusampayuttadukādi',
#  'pt24.3.': 'Hetuduka, Cūḷantaraduka',
#  'pt24.4.': 'Hetuduka, Āsavagocchaka',
#  'pt24.5.': 'Hetuduka, Saññojanagocchakādi',
#  'pt24.6.': 'Hetuduka, Mahantaraduka',
#  'pt24.7.': 'Hetuduka, Upādānagocchaka',
#  'pt24.8.': 'Hetuduka, Kilesagocchaka',
#  'pt24.9.': 'Hetuduka, Piṭṭhiduka',
#  'pt24.10.': 'Sahetukadukādi, Hetuduka',
#  'pt24.11.': 'Cūḷantaraduka, Hetuduka',
#  'pt24.12.': 'Āsavagocchaka, Hetuduka',
#  'pt24.13.': 'Mahantaradukādi, Hetuduka',
#  'pt24.14.': 'Saraṇaduka, Hetuduka',
#  'pt24.15.': 'Saraṇaduka, Sahetukaduka',
#  'pt24.16.': 'Saraṇaduka, Hetusampayuttaduka',
#  'pt24.17.': 'Saraṇaduka, Hetusahetukadukādi',
#  'pt24.18.': 'Saraṇaduka, Nahetusahetukaduka',
#  'pt24.19.': 'Saraṇaduka, Cūḷantaraduka',
#  'pt24.20.': 'Saraṇaduka, Āsavagocchakādi',
#  'pt24.21.': 'Saraṇaduka, Mahantaradukādi',
#  'pt24.22.': 'Saraṇaduka, Piṭṭhiduka'}

# %%
abhidhamma_index = {
    "Dhammasangani": ds_index,
    "Vibhanga": vb_index,
    "Dhatukatha": dt_index,
    "Kathavatthu": kv_index,
    "Puggalapannatti": pp_index, 
    "Yamaka": ya_index,
    "Patthana": {}
}

with open("../abhidhamma_index.json", "w", encoding="utf-8") as f:
    json.dump(abhidhamma_index, f, ensure_ascii=False, indent=4)

# %%
pakarana = df_index[df_index['verse_id'].str.split(":", n=1).str[1]=='0.1']


pakarana['text'].unique()
# Out:
# <ArrowStringArray>
# [   'Dhammasaṅgaṇī ',         'Vibhaṅga ',       'Dhātukathā ',
#   'Puggalapaññatti ',      'Kathāvatthu ', '10 Indriyayamaka ',
#   '3 Āyatanayamaka ',    '5 Saccayamaka ',  '2 Khandhayamaka ',
#     '4 Dhātuyamaka ',  '7 Anusayayamaka ',     '1 Mūlayamaka ',
#    '9 Dhammayamaka ', '6 Saṅkhārayamaka ',    '8 Cittayamaka ',
#  'Paṭṭhānapakaraṇa ']
# Length: 16, dtype: str

# %%
df_index[df_index['verse_id'].str.split(":").str[1]=='0.2']
# Out:
#           verse_id                                     text
# 272    ds2.1.1:0.2                               2 Niddesa
# 927    ds2.3.2:0.2                               2 Niddesa
# 1127   ds2.2.2:0.2                               2 Niddesa
# 1194   ds2.1.9:0.2                               2 Niddesa
# 1227   ds2.3.1:0.2                               2 Niddesa
# ...            ...                                      ...
# 84415   pt2.13:0.2  Dhammānuloma (1), Dukapaṭṭhānapāḷi (2)
# 85442    pt2.4:0.2  Dhammānuloma (1), Dukapaṭṭhānapāḷi (2)
# 87427    pt2.5:0.2  Dhammānuloma (1), Dukapaṭṭhānapāḷi (2)
# 87676   pt2.11:0.2  Dhammānuloma (1), Dukapaṭṭhānapāḷi (2)
# 87989    pt2.1:0.2  Dhammānuloma (1), Dukapaṭṭhānapāḷi (2)
#
# [1102 rows x 2 columns]

# %%
# !uv pip install "psycopg[binary]"
# Out:
# Resolved 3 packages in 675ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)-------------------     0 B/4.44 MiB
# ⠙ Preparing packages... (0/1)------------------- 16.00 KiB/4.44 MiB
# ⠙ Preparing packages... (0/1)------------------- 32.00 KiB/4.44 MiB
# ⠙ Preparing packages... (0/1)------------------- 39.99 KiB/4.44 MiB
# ⠙ Preparing packages... (0/1)------------------- 53.33 KiB/4.44 MiB
# ⠙ Preparing packages... (0/1)------------------- 61.32 KiB/4.44 MiB
# ⠙ Preparing packages... (0/1)------------------- 61.40 KiB/4.44 MiB
# ⠙ Preparing packages... (0/1)------------------- 77.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 93.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 93.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 109.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 125.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 141.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 157.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 173.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 189.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 205.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 221.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 237.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 253.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 269.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 285.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 349.40 KiB/4.44 MiB
# ⠹ Preparing packages... (0/1)------------------- 541.40 KiB/4.44 MiB
# ⠸ Preparing packages... (0/1)------------------- 717.40 KiB/4.44 MiB
# ⠸ Preparing packages... (0/1)------------------- 877.40 KiB/4.44 MiB
# ⠸ Preparing packages... (0/1)------------------- 1.03 MiB/4.44 MiB
# ⠸ Preparing packages... (0/1)------------------- 1.17 MiB/4.44 MiB
# ⠼ Preparing packages... (0/1)------------------- 1.36 MiB/4.44 MiB
# ⠼ Preparing packages... (0/1)------------------- 1.53 MiB/4.44 MiB
# ⠼ Preparing packages... (0/1)------------------- 1.67 MiB/4.44 MiB
# ⠼ Preparing packages... (0/1)m------------------ 1.81 MiB/4.44 MiB
# ⠴ Preparing packages... (0/1)2m----------------- 1.97 MiB/4.44 MiB
# ⠴ Preparing packages... (0/1)---------------- 2.14 MiB/4.44 MiB
# ⠴ Preparing packages... (0/1)--------------- 2.32 MiB/4.44 MiB
# ⠴ Preparing packages... (0/1)m-------------- 2.48 MiB/4.44 MiB
# ⠦ Preparing packages... (0/1)0m------------- 2.64 MiB/4.44 MiB
# ⠦ Preparing packages... (0/1)30m------------ 2.78 MiB/4.44 MiB
# ⠦ Preparing packages... (0/1)----------- 2.95 MiB/4.44 MiB
# ⠦ Preparing packages... (0/1)---------- 3.14 MiB/4.44 MiB
# ⠧ Preparing packages... (0/1)---------- 3.32 MiB/4.44 MiB
# ⠧ Preparing packages... (0/1)---------- 3.48 MiB/4.44 MiB
# ⠧ Preparing packages... (0/1)---------- 3.65 MiB/4.44 MiB
# ⠧ Preparing packages... (0/1)---------- 3.79 MiB/4.44 MiB
# ⠇ Preparing packages... (0/1)---------- 3.98 MiB/4.44 MiB
# ⠇ Preparing packages... (0/1)---------- 4.13 MiB/4.44 MiB
# Prepared 1 package in 1.54s
# Installed 1 package in 1ms.2
#  + psycopg-binary==3.3.2

# %%
import psycopg


conn = psycopg.connect(
    host="localhost",          # Docker host
    port=5432,                 # Postgres port from docker-compose
    dbname="pali_canon_db",    # Database name
    user="pali_canon",         # DB user
    password="anicca"          # DB password
)

cur = conn.cursor()

# %%
from sqlmodel import SQLModel, Field, create_engine, Session
from typing import Optional, List, Dict
from sqlalchemy.dialects.postgresql import JSONB, ARRAY, FLOAT

# %%
import sys
sys.path.insert(0, '..')

from pali_text_models import Sutta, get_session

# %% [markdown]
# ## Vinaya

# %% [markdown]
# ## Graph Based Indices

# %%
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout
import matplotlib.pyplot as plt

# %% [markdown]
# #### Graph tests and Operations

# %%
# Use a Directed Graph to show "descends from"
G = nx.DiGraph()

# 1. Define nodes with a 'subset' attribute for their generation level
# Level 0: Grandparents
G.add_node("Grandpa Joe", subset=0)
G.add_node("Grandma Mary", subset=0)

# Level 1: Parents
G.add_nodes_from(["Dad", "Aunt Sue"], subset=1)

# Level 2: Children
G.add_nodes_from(["Me", "Brother", "Cousin"], subset=2)

# 2. Add the relationships (Edges)
relationships = [
    ("Grandpa Joe", "Dad"), ("Grandma Mary", "Dad"),
    ("Grandpa Joe", "Aunt Sue"), ("Grandma Mary", "Aunt Sue"),
    ("Dad", "Me"), ("Dad", "Brother"),
    ("Aunt Sue", "Cousin")
]
G.add_edges_from(relationships)

# %%
# Create the layout using the 'subset' attribute
pos = nx.multipartite_layout(G, subset_key="subset")

plt.figure(figsize=(10, 6))
nx.draw(G, pos, 
        with_labels=True, 
        node_color='lightgreen', 
        node_size=3000, 
        arrowsize=20, 
        font_size=10,
        edge_color='gray')

plt.title("Family Tree Hierarchy")
plt.show()

# %%
list(nx.descendants(G, "Grandpa Joe"))
# Out:
# ['Brother', 'Dad', 'Me', 'Cousin', 'Aunt Sue']

# %%
list(G.successors("Dad"))
# Out:
# ['Me', 'Brother']

# %%
nx.shortest_path(G, "Grandpa Joe", "Me")
# Out:
# ['Grandpa Joe', 'Dad', 'Me']

# %% [markdown]
# ### Canon Graph Index

# %%
graph_path = '../pali-canon-reader/svelte-app/public/Canon.graphml'

# %%
G = nx.DiGraph()

G.add_node("Canon", level=0)

G.add_node("Sutta", level=1, level_label='Pitaka')
G.add_node("Vinaya", level=1, level_label='Pitaka')
G.add_node("Abhidhamma", level=1, level_label='Pitaka')

G.add_node("Saṁyuttanikāya", level=2, level_label='Nikāya')
G.add_node("Dīghanikāya", level=2, level_label='Nikāya')
G.add_node('Majjhimanikāya', level=2, level_label='Nikāya')
G.add_node('Anguttaranikāya', level=2, level_label='Nikāya')
G.add_node('Khuddakanikāya', level=2, level_label='Nikāya')


G.add_node("Dhammasangani", level=2, id=1)
G.add_node("Vibhanga", level=2, id=2)
G.add_node("Dhatukatha", level=2, id=3)
G.add_node("Kathavatthu", level=2, id=4)
G.add_node("Puggalapannatti", level=2, id=5)
G.add_node("Yamaka", level=2, id=6)
G.add_node("Patthana", level=2, id=7)




relationships = [
    ("Canon", "Sutta"),
    ("Canon", "Vinaya"),
    ("Canon", "Abhidhamma"),

    
    ("Sutta", "Saṁyuttanikāya"),
    ("Sutta", "Dīghanikāya"),
    ("Sutta", "Majjhimanikāya"),
    ("Sutta", "Anguttaranikāya"),
    ("Sutta", "Khuddakanikāya"),

    ("Abhidhamma", "Dhammasangani"),
    ("Abhidhamma", "Vibhanga"),
    ("Abhidhamma", "Dhatukatha"),
    ("Abhidhamma", "Kathavatthu"),
    ("Abhidhamma", "Puggalapannatti"),
    ("Abhidhamma", "Yamaka"),
    ("Abhidhamma", "Patthana"),
]

G.add_edges_from(relationships)

# %%
def get_level_keys(d, level):
    """
    Returns a dictionary of keys at the given level mapped to their immediate child keys (if any).
    
    Args:
        d (dict): nested dictionary
        level (int): level to extract (1-based)
        
    Returns:
        dict: {key_at_level: list_of_immediate_children_keys}
    """
    if level < 1:
        raise ValueError("Level must be >= 1")
    
    if level == 1:
        # top-level keys → their immediate children
        return {k: list(v.keys()) if isinstance(v, dict) else [] for k, v in d.items()}
    
    # level > 1: traverse one level deeper recursively
    result = {}
    for v in d.values():
        if isinstance(v, dict):
            deeper = get_level_keys(v, level - 1)
            result.update(deeper)
    return result

# %% [markdown]
# ### SN subgraph

# %%
## Vaggasaṁyutta Level = 3
sn_path ='../data/sn-index-tree.json'
sn_index = json.load(open(sn_path, "r", encoding="utf-8"))

Vaggasaṁyutta_relationships = []

lvl_1 = get_level_keys(sn_index, 1)

vaggasaṁyutta_list = list(lvl_1.keys())

for node in vaggasaṁyutta_list:
    edge = ("Saṁyuttanikāya", node)
    Vaggasaṁyutta_relationships.append(edge)

    G.add_node(node, level=3, level_label='Vaggasaṁyutta')

G.add_edges_from(Vaggasaṁyutta_relationships)

# %%
## Saṁyutta Level = 3

samyutta_relationships = []

lvl_2 = get_level_keys(sn_index, 2)

samyutta_list = list(lvl_2.keys())

for k,v in lvl_2.items():
    name = k.split(".")[1]
    id = k.split(".")[0].split("sn")[1]
    G.add_node(k, name=name, level=4, id=id, level_label='Saṁyutta')


for node in vaggasaṁyutta_list:
    samyutta = [item for item in list(sn_index[node].keys())]
    edge = [(node, item) for item in samyutta]
    samyutta_relationships.extend(edge)
   



G.add_edges_from(samyutta_relationships)

# %%
## Vagga Level = 5
from itertools import chain

vagga_relationships = []

lvl_3 = get_level_keys(sn_index, 3)

vagga_list = list(lvl_3.keys())

for node in vagga_list:
    node_id = f"sn:{node}"
    #G.add_node(node_id, name=node, level=5, level_label='Vagga')
    


samyutta_dict = dict(chain.from_iterable(
    v.items() for v in sn_index.values()
))
samyutta_vagga_map = {key: list(inner_dict.keys()) for key, inner_dict in samyutta_dict.items()}

for node, vagga in samyutta_vagga_map.items():
    samyutta_label = node.split(".")[1]
    samyutta_id = node.split(".")[0]

    edge = [(node, f"{samyutta_id}:{vagga}") for vagga in vagga]

    vagga_relationships.extend(edge)


G.add_edges_from(vagga_relationships)

# %%
## Sutta Level = 6
sutta_relationships = []
sutta_dict = {}
sutta_vagga_map = {}
missing_suttas = []
empty_vagga = []


for k0, v0 in sn_index.items():
    for k1, v1 in v0.items():
        for k2, v2 in v1.items():
            sutta_dict[k2] = v2


for k,v in sutta_dict.items():

    sutta_list = [f"{key}:{value}" for key, value in v.items()]
    sutta_vagga_map[k] = sutta_list

sutta_list=[]


sutta_list = [item for sublist in list(sutta_vagga_map.values()) for item in sublist]

for node in sutta_list:
    G.add_node(node, name=node.split(":")[1], level=6, level_label='Sutta', reading_unit_id=node.split(":")[0], reading_unit=True)


for k,v in sutta_vagga_map.items():  
    for sutta in v:

        vagga = f"{sutta.split('.')[0]}:{k}"
        edge = [(vagga,sutta)]
        sutta_relationships.extend(edge)


G.add_edges_from(sutta_relationships)

# %% [markdown]
# ### DN subgraphs

# %%
dn_path ='../data/dn-index-tree.json'
dn_index = json.load(open(dn_path, "r", encoding="utf-8"))


## DN Vagga Level = 3
vagga_list = list(dn_index.keys())

for node in vagga_list:
    G.add_node( f"dn:{node}", name=node, level=3, level_label='Vagga')

dn_vagga_relationships = [("Dīghanikāya", f"dn:{node}") for node in vagga_list]

G.add_edges_from(dn_vagga_relationships)

## DN Sutta Level = 4
dn_sutta_relationships = []

for vagga, sutta_dict in dn_index.items():
    for sutta_id, sutta_name in sutta_dict.items():
        edge = [(f"dn:{vagga}", f"dn:{sutta_name}")]
        dn_sutta_relationships.extend(edge)



        G.add_node(f"dn:{sutta_name}", name=sutta_name, level=4, level_label='Sutta', reading_unit_id=sutta_id, reading_unit=True)





G.add_edges_from(dn_sutta_relationships)

# %% [markdown]
# ### MN subgraph

# %%
mn_path ='../data/mn-name_root-misc-site.json'
mn_index = json.load(open(mn_path, "r", encoding="utf-8"))




mn_index = {k.split(":", 1)[1]: v for k, v in mn_index.items()}

l3_edges = []
l4_edges = []
l5_edges = []

for k,v in mn_index.items():

    #level 3 edges and nodes
    if v.endswith('paṇṇāsa'):
        node_id = f"mn:{v}"
        G.add_node(node_id, name=v, level=3, level_label='Paṇṇāsa')
        l3_edges.append(('Majjhimanikāya',node_id))
        pannasa = node_id

    #level 4 edges
    elif v.endswith('vagga'):
        node_id = f"mn:{v}"
        G.add_node(node_id, name=v, level=4, level_label='Vagga')
        l4_edges.append((pannasa, node_id))
        vagga = node_id

    #level 5 edges
    elif v.endswith('sutta'):
        unit_id = k.split(".")[1]
        node_id = f"mn:{v}"
        G.add_node(node_id, name=v, level=5, level_label='Sutta', reading_unit_id=unit_id, reading_unit=True)
        l5_edges.append((vagga,node_id))



G.add_edges_from(l3_edges)
G.add_edges_from(l4_edges)
G.add_edges_from(l5_edges)


# G.remove_edges_from(l3_edges)
# G.remove_edges_from(l4_edges)
# G.remove_edges_from(l5_edges)

# %% [markdown]
# ### AN Sub-graph

# %% [markdown]
# ### Abidhamma Subgraph

# %%
# Vibhanga Level = 3
abhidhamma_path ='../data/abhidhamma_index.json' 
abhidhamma_index = json.load(open(abhidhamma_path, "r", encoding="utf-8"))



vb_list = [f"{k}:{v}" for k, v in abhidhamma_index['Vibhanga'].items()]

vb_relationships = []

for node in vb_list:
    G.add_node(node, name=node.split(":")[1], level=3, level_label='Vibhanga', reading_unit_id=node.split(":")[0], reading_unit=True)

    edge = [("Vibhanga", node)]
    vb_relationships.extend(edge)


G.add_edges_from(vb_relationships)

# %%
ya_lvl3 = list(abhidhamma_index['Yamaka'].keys())


for node in ya_lvl3:
    G.add_node(node, name=node.split(".")[1], level=3, level_label='Yamaka')


ya_lvl3_relationships = []

for node in ya_lvl3:
    edge = [("Yamaka", f"{node}")]
    ya_lvl3_relationships.extend(edge)


G.add_edges_from(ya_lvl3_relationships)

# %% [markdown]
# ### Save Graph

# %%
nx.write_graphml(G, graph_path)

# %%
G.remove_nodes_from(list(nx.isolates(G)))
