# %%
import os
import json
import glob
import numpy as np
from pathlib import Path
import pandas as pd
import pyarrow as pa

import tqdm

from natsort import natsorted, index_natsorted


from gensim.models import Word2Vec, FastText 
from gensim.models.doc2vec import Doc2Vec, TaggedDocument


from nltk.tokenize import word_tokenize, sent_tokenize
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/oceansxyz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/oceansxyz/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# #### Word2Vec Testing

# %%
df = pd.read_csv("pali_canon.csv", index_col='index')

# %%
df_processed = df[df["sutta_id"] == "mn1"]["text"].copy()
df_processed = df_processed.str.lower()

if "mn1:0.1" in df_processed.index:
    df_processed = df_processed.drop(index='mn1:0.1')




df_processed.head()
# Out:
# index
# mn1:0.2                                   mūlapariyāyasutta
# mn1:1.1                                       evaṁ me sutaṁ—
# mn1:1.2    ekaṁ samayaṁ bhagavā ukkaṭṭhāyaṁ viharati subh...
# mn1:1.3                 tatra kho bhagavā bhikkhū āmantesi:
# mn1:1.4                                      “bhikkhavo”ti.
# Name: text, dtype: str

# %%
chunks = list(df_processed)

chunks[13]
# Out:
# 'pathaviṁ pathavito saññatvā pathaviṁ maññati, pathaviyā maññati, pathavito maññati, pathaviṁ meti maññati, pathaviṁ abhinandati. '

# %%
word_tokens = [word_tokenize(chunk.lower()) for chunk in chunks]

# %%
model = Word2Vec(
    sentences=word_tokens,
    vector_size=100,   # small for testing
    window=5,          # context window size
    min_count=1,       # include all words
    workers=4,         # CPU threads
    sg=1               # skip-gram model
)

# %%
word = "bhagavā"
if word in model.wv:
    print(f"Vector for '{word}':\n", model.wv[word][:10], "...")  # first 10 dims
    # Find similar words
    print("Most similar words:", model.wv.most_similar(word, topn=5))
else:
    print(f"'{word}' not in vocabulary")
# Out:
# Vector for 'bhagavā':
#  [-0.00650317  0.00127647 -0.00190314  0.00905263  0.00979077 -0.0243803
#   0.01041334  0.04735521 -0.02808947 -0.02143994] ...
# Most similar words: [('bhikkhave', 0.9459238648414612), ('bhikkhu', 0.9452006816864014), (',', 0.9450480341911316), ('nibbānato', 0.9446079134941101), ('maññati', 0.9443570971488953)]

# %%
sent_tokenize(chunks[13])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sent_tokenize(chunks[13])[1]
#
# IndexError: list index out of range

# %% [markdown]
# ### Document2Vec Sentence Embeddings

# %%
text_path = '../data/reading_units_202603121439.csv'

text_df = pd.read_csv(text_path, index_col='index')


text_list = text_df[['text']].squeeze()

text_list.head()
# Out:
# index
# tha-ap393:74.1     Saṭṭhi tūriyasahassāni,
# tha-ap393:74.2        bheriyo samalaṅkatā;
# tha-ap393:74.3    Vajjayissantimaṁ niccaṁ,
# tha-ap393:74.4     sabbadānassidaṁ phalaṁ.
# tha-ap393:75.1         Chaḷāsītisahassāni,
# Name: text, dtype: str

# %%
type(text_list)
# Out:
# pandas.Series

# %%
#
class DocGenerator:
    def __init__(self, series):
        self.series = series
        

    def __iter__(self):
        for idx, text in self.series.items():
            yield TaggedDocument(words=str(text).lower().split(), tags=[str(idx)])

doc_stream = DocGenerator(text_list)

# %%
model = Doc2Vec(vector_size=100, window=5, min_count=2, workers=4, epochs=20)
model.build_vocab(doc_stream)
model.train(doc_stream, total_examples=model.corpus_count, epochs=model.epochs)

# %%
print(len(model.dv))
# Out:
# 373122

# %%
print(len(model.wv))
# Out:
# 99390

# %%
model.save("canon_doc2vec_v0.model")

# %%
mode_l = Doc2Vec.load("canon_doc2vec_v0.model")

# %%
len(mode_l.dv)
# Out:
# 373122
